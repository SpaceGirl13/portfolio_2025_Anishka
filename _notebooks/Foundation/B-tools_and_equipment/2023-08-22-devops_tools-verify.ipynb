# %% [raw]
# ---
# layout: post
# title: Tools Verify using Shell
# description: Linux and the shell is used in this example to setup and verify the installation of the tools.  Additionally, a few programming exercises are included.
# categories: [DevOps]
# permalink: /devops/tools/verify
# menu: nav/tools_setup.html
# toc: true
# comments: true
# ---

# %% [markdown]
# ## Computers and Terminals
#
# A brief overview of Terminal and Linux is a step on your way to becoming a Linux expert. When a computer boots up, **a kernel (MacOS, Windows, Linux) is started**. This kernel is the core of the operating system and manages hardware resources. Above the kernel, various applications run, including the **shell** and **terminal**, which allow users to interact with the system using a basic set of commands provided by the kernel.
#
# Typically, casual users interact with the system through a Desktop User Interface (UI) that is started by the computer's boot-up processes. However, to interact directly with the shell, users can run a "terminal" application through the Desktop UI. Additionally, **VS Code provides the ability to activate a "terminal"** within its editing environment, making it convenient for developers to execute commands without leaving the code editor.
#
# In this next phase, we will use a Jupyter notebook to perform Linux commands through a terminal. The Jupyter notebook is an application that runs above the kernel, providing an interactive environment for writing and executing code, including shell commands. This setup allows us to seamlessly integrate code execution, data analysis, and documentation in one place, enhancing our productivity and learning experience.

# %% [markdown]
# ## Setup a Personal GitHub Pages Project
#
# You will be making a personal copy of the course repository. Be sure to have a GitHub account!!!
#
# - Use the **Green "Use this Template"** button on the [portfolio_2025](https://github.com/nighthawkcoders/portfolio_2025) repository page to set up your personal GitHub Pages repository.
# - Create a new repository.
# - Fill in the dialog and select the **Repository Name** to be under your GitHub ID ownership.
#
#     ![create repo]({{ site.baseurl }}/images/notebooks/foundation/create_repo.jpg)
#
# - After this is complete, use the **Green "Code"** button on the newly created repository page to capture your "Project Repo" name.
#
# In the next few code cells, we will run a bash (shell) script to pull a GitHub project.

# %% [markdown]
# ## Shell Script and Variables
#
# We will ultimately run a bash (shell) script to pull a GitHub project. This next script simply sets up the necessary **environment variables** to tell the script the location of repository from GitHub and where to copy the output.
#
# For now, focus on each line that begins with `export`. These are **shell variables**. Each line has a **name** (after the keyword `export`) and a **value** (after the equal sign).
#
# Here is a full description:
#
# - **Creates a temporary file** `/tmp/variables.sh` to store environment variables.
# - **Sets the `project_dir` variable** to your home directory with a subdirectory named `nighthawk`. You can change `nighthawk` to a different name to test your git clone.
# - **Sets the `project` variable** to a subdirectory within `project_dir` named `portfolio_2025`. You can change `portfolio_2025` to the name of your project.
# - **Sets the `project_repo` variable** to the URL of the GitHub repository. Change this to the project you created from the `portfolio_2025` template.
#
# **By running this script, you will prepare your environment for cloning** and working on your GitHub project. This is an essential step in setting up your development environment and ensuring that all dependencies are correctly configured.

# %%
# %%script bash
#
# # Dependency Variables, set to match your project directories
#
# cat <<EOF > /tmp/variables.sh
# export project_dir=$HOME/nighthawks  # change nighthawk to different name to test your git clone
# export project=\$project_dir/portfolio_2025_Anishka  # change portfolio_2025 to name of project from git clone
# export project_repo="https://github.com/spacegirl13/portfolio_2025_Anishka"  # change to project you created from portfolio_2025 template
# EOF

# %% [markdown]
# ## Describing the Outputs of the Variables
#
# The next script will extract the saved variables and display their values. Here is a description of the commands:
#
# - The `source` command loads the variables that we saved in the `/tmp/variables.sh` file in the previous code cell.
# - The `echo` commands display the contents of the named variables:
#   - **project_dir**: The directory where your project is located.
#   - **project**: The specific project directory within `project_dir`.
#   - **project_repo**: The URL of the GitHub repository.
#
# By running this script, you can verify that the environment variables are correctly set in your development environment. If they don't match up, go back to the previous code cell and make the necessary corrections.

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# # Output shown title and value variables
# echo "Project dir: $project_dir"
# echo "Project: $project"
# echo "Repo: $project_repo"
# Out:
# Project dir: /Users/anishkasanghvi/nighthawks
# Project: /Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka
# Repo: https://github.com/spacegirl13/portfolio_2025_Anishka

# %% [markdown]
# ## Project Setup and Analysis with Bash Scripts
# The bash scripts that follow automate what was done in the Tools Installation procedures with regards to cloning a GitHub project. Doing this in a script fashion adds the following benefits:
#
# - After completing these steps, we will have notes on how to set up and verify a project.
# - By reviewing these commands, you will start to learn the basics of Linux.
# - By setting up these code cells, you will be learning how to develop automated scripts using Shell programming.
# - You will learn that pretty much anything we type on a computer can be automated through the use of variables and a coding language.

# %% [markdown]
# ### Pull Code
#
# > Pull code from GitHub to your machine. This is a **bash script**, a sequence of commands, that will create a project directory and add the "project" from GitHub to the vscode directory. There is conditional logic to make sure that the clone only happens if it does not (!) exist. Here are some key elements in this code:
#
# - `cd` command (change directory), remember this from the terminal session.
# - `if` statements (conditional statements, called selection statements by College Board), code inside only happens if the condition is met.
#
# Run the script two times and you will see that the output changes.  In the second run, the files exist and it impact the flow of the code.

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Using conditional statement to create a project directory and project"
#
# cd ~    # start in home directory
#
# # Conditional block to make a project directory
# if [ ! -d $project_dir ]
# then
#     echo "Directory $project_dir does not exist... making directory $project_dir"
#     mkdir -p $project_dir
# fi
# echo "Directory $project_dir exists."
#
# # Conditional block to git clone a project from project_repo
# if [ ! -d $project ]
# then
#     echo "Directory $project does not exist... cloning $project_repo"
#     cd $project_dir
#     git clone $project_repo
#     cd ~
# fi
# echo "Directory $project exists."
# Out:
# Using conditional statement to create a project directory and project
# Directory /Users/anishkasanghvi/nighthawks exists.
# Directory /Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka exists.

# %% [markdown]
# ### Look at Files in GitHub Project
#
# > All computers contain files and directories. The clone brought more files from the cloud to your machine. Review the bash shell script, observe the commands that show and interact with files and directories. These were used during setup.
#
# - `ls` lists computer files in Unix and Unix-like operating systems.
# - `cd` offers a way to navigate and change the working directory.
# - `pwd` prints the working directory.
# - `echo` is used to display a line of text/string that is passed as an argument.

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Navigate to project, then navigate to area wwhere files were cloned"
# cd $project
# pwd
#
# echo ""
# echo "list top level or root of files with project pulled from github"
# ls
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# /Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka
#
# list top level or root of files with project pulled from github
# 404.html
# Gemfile
# LICENSE
# Makefile
# README.md
# README4YML.md
# _config.yml
# _data
# _includes
# _layouts
# _notebooks
# _posts
# _sass
# assets
# design
# images
# index.md
# kasm_design
# navigation
# node_backend
# requirements.txt
# scripts

# %% [markdown]
# ### Look at File List with Hidden and Long Attributes
#
# > Most Linux commands have options to enhance behavior. The enhanced listing below shows permission bits, owner of the file, size, and date.
#
# Some useful `ls` flags:
# - `-a`: List all files including hidden files.
# - `-l`: List in long format.
# - `-h`: Human-readable file sizes.
# - `-t`: Sort by modification time.
# - `-R`: Reverse the order of the sort.
#
# [ls reference](https://www.rapidtables.com/code/linux/ls.html)

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Navigate to project, then navigate to area wwhere files were cloned"
# cd $project
# pwd
#
# echo ""
# echo "list all files in long format"
# ls -al   # all files -a (hidden) in -l long listing
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# /Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka
#
# list all files in long format
# total 168
# drwxr-xr-x  28 anishkasanghvi  staff    896 Dec 10 11:58 .
# drwxr-xr-x   5 anishkasanghvi  staff    160 Dec  6 12:38 ..
# -rw-r--r--@  1 anishkasanghvi  staff  10244 Dec 10 12:17 .DS_Store
# drwxr-xr-x  13 anishkasanghvi  staff    416 Dec 12 11:37 .git
# drwxr-xr-x   3 anishkasanghvi  staff     96 Dec  6 12:38 .github
# -rw-r--r--   1 anishkasanghvi  staff    455 Dec  6 12:38 .gitignore
# -rw-r--r--   1 anishkasanghvi  staff    436 Dec  6 12:38 404.html
# -rw-r--r--   1 anishkasanghvi  staff    122 Dec  6 12:38 Gemfile
# -rw-r--r--@  1 anishkasanghvi  staff  11357 Dec  6 12:38 LICENSE
# -rw-r--r--   1 anishkasanghvi  staff   5526 Dec  6 12:38 Makefile
# -rw-r--r--   1 anishkasanghvi  staff  14185 Dec  6 12:38 README.md
# -rw-r--r--   1 anishkasanghvi  staff     99 Dec  6 12:38 README4YML.md
# -rw-r--r--   1 anishkasanghvi  staff    881 Dec  6 12:38 _config.yml
# drwxr-xr-x   8 anishkasanghvi  staff    256 Dec  6 12:38 _data
# drwxr-xr-x  21 anishkasanghvi  staff    672 Dec  6 12:38 _includes
# drwxr-xr-x   9 anishkasanghvi  staff    288 Dec  6 12:38 _layouts
# drwxr-xr-x   9 anishkasanghvi  staff    288 Dec 10 11:58 _notebooks
# drwxr-xr-x  16 anishkasanghvi  staff    512 Dec  6 12:38 _posts
# drwxr-xr-x   7 anishkasanghvi  staff    224 Dec  6 12:38 _sass
# drwxr-xr-x   6 anishkasanghvi  staff    192 Dec  6 12:38 assets
# drwxr-xr-x   3 anishkasanghvi  staff     96 Dec  6 12:38 design
# drwxr-xr-x  39 anishkasanghvi  staff   1248 Dec  6 12:38 images
# -rw-r--r--   1 anishkasanghvi  staff  12193 Dec  6 12:38 index.md
# drwxr-xr-x  13 anishkasanghvi  staff    416 Dec  6 12:38 kasm_design
# drwxr-xr-x  13 anishkasanghvi  staff    416 Dec  6 12:38 navigation
# drwxr-xr-x   8 anishkasanghvi  staff    256 Dec  6 12:38 node_backend
# -rw-r--r--@  1 anishkasanghvi  staff     57 Dec  6 12:38 requirements.txt
# drwxr-xr-x  18 anishkasanghvi  staff    576 Dec  6 12:38 scripts

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Look for posts"
# export posts=$project/_posts  # _posts inside project
# cd $posts  # this should exist per fastpages
# pwd  # present working directory
# ls -lR  # list posts recursively
# Out:
# Look for posts
# /Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka/_posts
# total 240
# -rw-r--r--   1 anishkasanghvi  staff   4326 Dec  6 12:38 2023-08-21-python_flask.md
# -rw-r--r--   1 anishkasanghvi  staff  11348 Dec  6 12:38 2023-08-30-agile_methodolgy.md
# -rw-r--r--   1 anishkasanghvi  staff   6265 Dec  6 12:38 2023-08-31-javascript_project-binary-calculator.md
# -rw-r--r--   1 anishkasanghvi  staff   6712 Dec  6 12:38 2023-08-31-javascript_project-calculator.md
# -rw-r--r--   1 anishkasanghvi  staff   5707 Dec  6 12:38 2023-08-31-javascript_project-game-of-life.md
# -rw-r--r--   1 anishkasanghvi  staff   3811 Dec  6 12:38 2023-08-31-javascript_project-music-api.md
# -rw-r--r--   1 anishkasanghvi  staff  14282 Dec  6 12:38 2023-08-31-javascript_project-snake-game.md
# -rw-r--r--   1 anishkasanghvi  staff   3683 Dec  6 12:38 2023-09-12-python-flask-repo.md
# -rw-r--r--   1 anishkasanghvi  staff  48002 Dec  6 12:38 2023-10-03-java-types-student-2.ipynb
# -rw-r--r--   1 anishkasanghvi  staff    257 Dec  6 12:38 2024-09-19-bathroom_pass.md
# drwxr-xr-x   3 anishkasanghvi  staff     96 Dec  6 12:38 CSA
# drwxr-xr-x   3 anishkasanghvi  staff     96 Dec  6 12:38 CSP
# drwxr-xr-x  13 anishkasanghvi  staff    416 Dec  6 12:38 CSSE
# drwxr-xr-x   4 anishkasanghvi  staff    128 Dec  6 12:38 Kasm
#
# ./CSA:
# total 0
# drwxr-xr-x  3 anishkasanghvi  staff  96 Dec  6 12:38 chatgpt
#
# ./CSA/chatgpt:
# total 8
# -rw-r--r--  1 anishkasanghvi  staff  2698 Dec  6 12:38 2024-07-11-GPTchatbot.md
#
# ./CSP:
# total 0
# drwxr-xr-x  5 anishkasanghvi  staff  160 Dec  6 12:38 big-ideas
#
# ./CSP/big-ideas:
# total 0
# drwxr-xr-x  3 anishkasanghvi  staff  96 Dec  6 12:38 big-idea-1
# drwxr-xr-x  3 anishkasanghvi  staff  96 Dec  6 12:38 big-idea-2
# drwxr-xr-x  3 anishkasanghvi  staff  96 Dec  6 12:38 big-idea-3-part-1-fundamentals
#
# ./CSP/big-ideas/big-idea-1:
# total 8
# -rw-r--r--  1 anishkasanghvi  staff  3229 Dec  6 12:38 2024-12-02-creative_development_video.md
#
# ./CSP/big-ideas/big-idea-2:
# total 24
# -rw-r--r--  1 anishkasanghvi  staff  9556 Dec  6 12:38 2024-12-03-binary_logic.md
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals:
# total 0
# drwxr-xr-x  3 anishkasanghvi  staff  96 Dec  6 12:38 Period5
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period5:
# total 0
# drwxr-xr-x  3 anishkasanghvi  staff  96 Dec  6 12:38 aaak
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period5/aaak:
# total 8
# -rw-r--r--  1 anishkasanghvi  staff  2141 Dec  6 12:38 2024-09-24-3.1-py-hacks.ipynb
#
# ./CSSE:
# total 120
# -rw-r--r--  1 anishkasanghvi  staff  4104 Dec  6 12:38 2023-11-13-CSSE-tri2-oop1.md
# -rw-r--r--  1 anishkasanghvi  staff  6991 Dec  6 12:38 2023-11-27-CSSE-tri2-oop2.md
# -rw-r--r--  1 anishkasanghvi  staff  1545 Dec  6 12:38 2023-11-28-CSSE-animation.md
# -rw-r--r--  1 anishkasanghvi  staff  1381 Dec  6 12:38 2023-11-28-CSSE-enemies.md
# -rw-r--r--  1 anishkasanghvi  staff  1359 Dec  6 12:38 2023-11-28-CSSE-leaderboard.md
# -rw-r--r--  1 anishkasanghvi  staff  2089 Dec  6 12:38 2023-11-28-CSSE-parallax.md
# -rw-r--r--  1 anishkasanghvi  staff  1057 Dec  6 12:38 2023-11-28-CSSE-platforms.md
# -rw-r--r--  1 anishkasanghvi  staff   732 Dec  6 12:38 2023-11-28-CSSE-player.md
# -rw-r--r--  1 anishkasanghvi  staff  1015 Dec  6 12:38 2023-11-28-CSSE-selection.md
# -rw-r--r--  1 anishkasanghvi  staff  6265 Dec  6 12:38 2023-12-05-CSSE-student-enemy_lesson.md
# -rw-r--r--  1 anishkasanghvi  staff  4118 Dec  6 12:38 2023-12-20-CSSE_student_player.md
#
# ./Kasm:
# total 0
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 Config_Guides
# drwxr-xr-x  4 anishkasanghvi  staff  128 Dec  6 12:38 MultiServer
#
# ./Kasm/Config_Guides:
# total 8
# -rw-r--r--  1 anishkasanghvi  staff  3167 Dec  6 12:38 2024-07-12-terraform-vs-ansible.md
#
# ./Kasm/MultiServer:
# total 160
# -rw-r--r--  1 anishkasanghvi  staff  55630 Dec  6 12:38 2024-07-12-multiserver-development.md
# -rw-r--r--  1 anishkasanghvi  staff  21730 Dec  6 12:38 2024-07-12-multiserver-install.md

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Look for notebooks"
# export notebooks=$project/_notebooks  # _notebooks is inside project
# cd $notebooks   # this should exist per fastpages
# pwd  # present working directory
# ls -lR  # list notebooks recursively
# Out:
# Look for notebooks
# /Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka/_notebooks
# total 24
# -rw-r--r--   1 anishkasanghvi  staff  10436 Dec  6 12:38 2023-08-23-jupyter-notebook-python.ipynb
# drwxr-xr-x  10 anishkasanghvi  staff    320 Dec  6 12:38 CSA
# drwxr-xr-x   7 anishkasanghvi  staff    224 Dec  6 12:38 CSP
# drwxr-xr-x  14 anishkasanghvi  staff    448 Dec  6 12:38 CSSE
# drwxr-xr-x   9 anishkasanghvi  staff    288 Dec  6 12:38 Foundation
# drwxr-xr-x   7 anishkasanghvi  staff    224 Dec  6 12:38 KASM
#
# ./CSA:
# total 56
# -rw-r--r--   1 anishkasanghvi  staff   7656 Dec  6 12:38 2024-10-06-sprint2_plan.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  13861 Dec  6 12:38 2024-10-29-sprint3_plan.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   3576 Dec  6 12:38 2024-11-12-sprint4_plan.ipynb
# drwxr-xr-x   4 anishkasanghvi  staff    128 Dec  6 12:38 chatgpt
# drwxr-xr-x   7 anishkasanghvi  staff    224 Dec  6 12:38 fullstack_java
# drwxr-xr-x   9 anishkasanghvi  staff    288 Dec  6 12:38 spring_boot
# drwxr-xr-x  12 anishkasanghvi  staff    384 Dec  6 12:38 units_1_to_10
# drwxr-xr-x  11 anishkasanghvi  staff    352 Dec  6 12:38 units_1_to_10_quiz
#
# ./CSA/chatgpt:
# total 40
# -rw-r--r--  1 anishkasanghvi  staff  6512 Dec  6 12:38 2024-07-16-chatgpt-code.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  8992 Dec  6 12:38 2024-07-16-chatgpt-intro.ipynb
#
# ./CSA/fullstack_java:
# total 104
# -rw-r--r--  1 anishkasanghvi  staff   4384 Dec  6 12:38 2024-07-21-Fullstack-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12072 Dec  6 12:38 2024-07-22-Fullstack-backend.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2909 Dec  6 12:38 2024-07-22-Fullstack-design.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8793 Dec  6 12:38 2024-07-22-Fullstack-example.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  16364 Dec  6 12:38 2024-07-22-Fullstack-frontend.ipynb
#
# ./CSA/spring_boot:
# total 176
# -rw-r--r--  1 anishkasanghvi  staff  13861 Dec  6 12:38 2023-10-14-java-spring-anatomy.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3465 Dec  6 12:38 2023-10-15-java-spring-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7862 Dec  6 12:38 2023-10-16-java-spring-ui.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9170 Dec  6 12:38 2023-10-17-java-spring-api.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  25586 Dec  6 12:38 2023-10-17-java-spring-pojo.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9449 Dec  6 12:38 2023-10-18-java-spring-jpa.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5203 Dec  6 12:38 2023-10-22-java-spring-hacks.ipynb
#
# ./CSA/units_1_to_10:
# total 0
# drwxr-xr-x  11 anishkasanghvi  staff  352 Dec  6 12:38 backup_summer_2024
# drwxr-xr-x   3 anishkasanghvi  staff   96 Dec  6 12:38 unit_01
# drwxr-xr-x   3 anishkasanghvi  staff   96 Dec  6 12:38 unit_02
# drwxr-xr-x   3 anishkasanghvi  staff   96 Dec  6 12:38 unit_03
# drwxr-xr-x   3 anishkasanghvi  staff   96 Dec  6 12:38 unit_04
# drwxr-xr-x   4 anishkasanghvi  staff  128 Dec  6 12:38 unit_05
# drwxr-xr-x   4 anishkasanghvi  staff  128 Dec  6 12:38 unit_06
# drwxr-xr-x   4 anishkasanghvi  staff  128 Dec  6 12:38 unit_07
# drwxr-xr-x   4 anishkasanghvi  staff  128 Dec  6 12:38 unit_08
# drwxr-xr-x   3 anishkasanghvi  staff   96 Dec  6 12:38 unit_09
#
# ./CSA/units_1_to_10/backup_summer_2024:
# total 488
# -rw-r--r--  1 anishkasanghvi  staff  13873 Dec  6 12:38 2024-06-24-unit_2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  17130 Dec  6 12:38 2024-06-24-unit_3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11417 Dec  6 12:38 2024-06-24-unit_4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  17643 Dec  6 12:38 2024-06-24-unit_5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  31061 Dec  6 12:38 2024-06-24-unit_6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  42181 Dec  6 12:38 2024-06-29-unit_7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  42585 Dec  6 12:38 2024-07-02-unit_8.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  55621 Dec  6 12:38 2024-07-08-unit_9.ipynb
# drwxr-xr-x  6 anishkasanghvi  staff    192 Dec  6 12:38 units_1_to_10_examples
#
# ./CSA/units_1_to_10/backup_summer_2024/units_1_to_10_examples:
# total 40
# -rw-r--r--  1 anishkasanghvi  staff  3891 Dec  6 12:38 2024-06-24-unit_2_examples.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3004 Dec  6 12:38 2024-06-24-unit_3_examples.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3954 Dec  6 12:38 2024-06-24-unit_4_examples.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  4446 Dec  6 12:38 2024-06-24-unit_5_examples.ipynb
#
# ./CSA/units_1_to_10/unit_01:
# total 0
# drwxr-xr-x  8 anishkasanghvi  staff  256 Dec  6 12:38 Teacher
#
# ./CSA/units_1_to_10/unit_01/Teacher:
# total 128
# -rw-r--r--  1 anishkasanghvi  staff   2171 Dec  6 12:38 2024-06-23-unit_1._intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5159 Dec  6 12:38 2024-06-24-unit_1_primatives.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2389 Dec  6 12:38 2024-06-24-unit_1_reference.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8227 Dec  6 12:38 2024-06-24-unit_1_stack_heap.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  28540 Dec  6 12:38 2024-07-01-unit_1_examples.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5424 Dec  6 12:38 2024-07-13-unit_1_quiz.ipynb
#
# ./CSA/units_1_to_10/unit_02:
# total 0
# drwxr-xr-x  8 anishkasanghvi  staff  256 Dec  6 12:38 Period3
#
# ./CSA/units_1_to_10/unit_02/Period3:
# total 136
# -rw-r--r--  1 anishkasanghvi  staff   3930 Dec  6 12:38 2024-09-12-Unit_2_HW.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2285 Dec  6 12:38 2024-09-12-Unit_2_home.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11254 Dec  6 12:38 2024-09-12-Unit_2_part1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  18063 Dec  6 12:38 2024-09-12-Unit_2_part2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  15972 Dec  6 12:38 2024-09-13-Unit_2_part3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10321 Dec  6 12:38 2024-09-16-Unit_2_part4.ipynb
#
# ./CSA/units_1_to_10/unit_03:
# total 0
# drwxr-xr-x  11 anishkasanghvi  staff  352 Dec  6 12:38 Period1
#
# ./CSA/units_1_to_10/unit_03/Period1:
# total 104
# -rw-r--r--  1 anishkasanghvi  staff  4121 Dec  6 12:38 2024-09-12-U3-0-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3506 Dec  6 12:38 2024-09-12-U3-1-Boolean.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  2811 Dec  6 12:38 2024-09-15-unit3_teamteach_3.2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3686 Dec  6 12:38 2024-09-15-unit3_teamteach_3.3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3628 Dec  6 12:38 2024-09-15-unit3_teamteach_3.4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6921 Dec  6 12:38 2024-09-15-unit3_teamteach_3.5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3561 Dec  6 12:38 2024-09-15-unit3_teamteach_3.6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6427 Dec  6 12:38 2024-09-15-unit3_teamteach_3.7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5413 Dec  6 12:38 2024-09-16-unit_teamteach_hw.ipynb
#
# ./CSA/units_1_to_10/unit_04:
# total 0
# drwxr-xr-x  8 anishkasanghvi  staff  256 Dec  6 12:38 Period1
#
# ./CSA/units_1_to_10/unit_04/Period1:
# total 136
# -rw-r--r--  1 anishkasanghvi  staff   6364 Dec  6 12:38 2024-09-12-U4-Iteration.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9873 Dec  6 12:38 2024-09-19-unit_4.1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8450 Dec  6 12:38 2024-09-19-unit_4.2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10122 Dec  6 12:38 2024-09-19-unit_4.3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14314 Dec  6 12:38 2024-09-19-unit_4.4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6158 Dec  6 12:38 2024-09-19-unit_4_hwquiz.ipynb
#
# ./CSA/units_1_to_10/unit_05:
# total 0
# drwxr-xr-x   9 anishkasanghvi  staff  288 Dec  6 12:38 Period1
# drwxr-xr-x  13 anishkasanghvi  staff  416 Dec  6 12:38 Period3
#
# ./CSA/units_1_to_10/unit_05/Period1:
# total 128
# -rw-r--r--  1 anishkasanghvi  staff   4131 Dec  6 12:38 2024-09-12-U5-Writing_Classes_Intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5233 Dec  6 12:38 2024-09-12-U5-game.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6091 Dec  6 12:38 2024-09-16-p1_unit5_Anatomy.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5452 Dec  6 12:38 2024-09-16-p1_unit5_Mutators.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5036 Dec  6 12:38 2024-09-16-p1_unit5_StaticVariables.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4857 Dec  6 12:38 2024-09-16-p1_unit5_accessorMethods.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13062 Dec  6 12:38 2024-09-16-p1_unit5_constructors.ipynb
#
# ./CSA/units_1_to_10/unit_05/Period3:
# total 176
# -rw-r--r--  1 anishkasanghvi  staff  8935 Dec  6 12:38 2024-09-15-unit_5-constructors.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6952 Dec  6 12:38 2024-09-16-unit_5-classanatomy.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5688 Dec  6 12:38 2024-09-17-unit_5-accessor.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5966 Dec  6 12:38 2024-09-17-unit_5-mutator-methods.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5808 Dec  6 12:38 2024-09-17-unit_5-toString.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  7180 Dec  6 12:38 2024-09-17-unit_5-writing-methods.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  7229 Dec  6 12:38 2024-09-18-unit_5-static-variables-and-methods.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  8944 Dec  6 12:38 2024-09-19-unit_5-this-keyword.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1202 Dec  6 12:38 2024-09-22-unit_5-home.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5673 Dec  6 12:38 2024-09-22-unit_5-scope_access_hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1988 Dec  6 12:38 2024-09-23-unit_5-homework.ipynb
#
# ./CSA/units_1_to_10/unit_06:
# total 0
# drwxr-xr-x  7 anishkasanghvi  staff  224 Dec  6 12:38 Period1
# drwxr-xr-x  7 anishkasanghvi  staff  224 Dec  6 12:38 Period3
#
# ./CSA/units_1_to_10/unit_06/Period1:
# total 80
# -rw-r--r--  1 anishkasanghvi  staff   2194 Dec  6 12:38 2024-09-12-unit_6-0-homepage.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10966 Dec  6 12:38 2024-09-12-unit_6-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6931 Dec  6 12:38 2024-09-12-unit_6-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6643 Dec  6 12:38 2024-09-12-unit_6-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6409 Dec  6 12:38 2024-09-12-unit_6-4.ipynb
#
# ./CSA/units_1_to_10/unit_06/Period3:
# total 96
# -rw-r--r--  1 anishkasanghvi  staff   1281 Dec  6 12:38 2024-09-12-Unit-6-0-Home-Page.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11092 Dec  6 12:38 2024-09-13-Unit-6.1-Lesson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14447 Dec  6 12:38 2024-09-13-Unit-6.2-Lesson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5217 Dec  6 12:38 2024-09-16-Unit-6.3-Lesson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7736 Dec  6 12:38 2024-09-16-Unit-6.4-Lesson.ipynb
#
# ./CSA/units_1_to_10/unit_07:
# total 0
# drwxr-xr-x  10 anishkasanghvi  staff  320 Dec  6 12:38 Period1
# drwxr-xr-x   9 anishkasanghvi  staff  288 Dec  6 12:38 Period3
#
# ./CSA/units_1_to_10/unit_07/Period1:
# total 168
# -rw-r--r--  1 anishkasanghvi  staff   9754 Dec  6 12:38 2024-09-19-unit_7_p1-7.3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8127 Dec  6 12:38 2024-09-19-unit_7_p1-7.4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5846 Dec  6 12:38 2024-09-23-unit_7_p1-7.1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  18668 Dec  6 12:38 2024-09-23-unit_7_p1-7.2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9146 Dec  6 12:38 2024-09-23-unit_7_p1-7.5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8618 Dec  6 12:38 2024-09-23-unit_7_p1-7.6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6133 Dec  6 12:38 2024-09-23-unit_7_p1-7.7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   1849 Dec  6 12:38 2024-09-23-unit_7_p1-homepage.ipynb
#
# ./CSA/units_1_to_10/unit_07/Period3:
# total 128
# -rw-r--r--  1 anishkasanghvi  staff   2319 Dec  6 12:38 2024-09-10-Unit7TeamTeach_Ethics.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9920 Dec  6 12:38 2024-09-10-Unit7TeamTeach_Searching&algorithms.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12488 Dec  6 12:38 2024-09-10-Unit7TeamTeach_Sorting.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2601 Dec  6 12:38 2024-09-10-Unit7TeamTeach_hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3689 Dec  6 12:38 2024-09-10-Unit7TeamTeach_homePage.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8321 Dec  6 12:38 2024-09-10-Unit7TeamTeach_traversing.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8705 Dec  6 12:38 2024-09-10-Unit7TeamteachPeriod3.ipynb
#
# ./CSA/units_1_to_10/unit_08:
# total 0
# drwxr-xr-x  7 anishkasanghvi  staff  224 Dec  6 12:38 Period1
# drwxr-xr-x  7 anishkasanghvi  staff  224 Dec  6 12:38 Period3
#
# ./CSA/units_1_to_10/unit_08/Period1:
# total 112
# -rw-r--r--  1 anishkasanghvi  staff   1612 Dec  6 12:38 2024-09-12-U8-2D-Array-Accessing-Updating-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  25016 Dec  6 12:38 2024-09-12-U8-2D-Array-Algorithms-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4405 Dec  6 12:38 2024-09-12-U8-2D-Array-Declare-Initialize-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3398 Dec  6 12:38 2024-09-12-U8-2D-Array-Intro-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8627 Dec  6 12:38 2024-09-12-U8-2D-Array-Traversing-p1.ipynb
#
# ./CSA/units_1_to_10/unit_08/Period3:
# total 144
# -rw-r--r--  1 anishkasanghvi  staff  33337 Dec  6 12:38 2024-09-18-8.2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13415 Dec  6 12:38 2024-09-19-8.1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   1042 Dec  6 12:38 2024-09-19-Home.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7415 Dec  6 12:38 2024-09-23-Unit8-ImageConverter.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4443 Dec  6 12:38 2024-09-23-unit8-hw.ipynb
#
# ./CSA/units_1_to_10/unit_09:
# total 0
# drwxr-xr-x  9 anishkasanghvi  staff  288 Dec  6 12:38 Period3
#
# ./CSA/units_1_to_10/unit_09/Period3:
# total 168
# -rw-r--r--  1 anishkasanghvi  staff  16839 Dec  6 12:38 2023-09-12-U9-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2852 Dec  6 12:38 2023-09-12-U9-7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9152 Dec  6 12:38 2023-09-21-U9-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3135 Dec  6 12:38 2024-09-12-U9-0-Inheritance.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14528 Dec  6 12:38 2024-09-12-U9-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  15002 Dec  6 12:38 2024-09-12-U9-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10591 Dec  6 12:38 2024-09-18-U9-5.ipynb
#
# ./CSA/units_1_to_10_quiz:
# total 96
# -rw-r--r--  1 anishkasanghvi  staff  3658 Dec  6 12:38 2024-07-13-unit_2_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1656 Dec  6 12:38 2024-07-13-unit_3_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1473 Dec  6 12:38 2024-07-13-unit_4_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6515 Dec  6 12:38 2024-07-13-unit_5_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5533 Dec  6 12:38 2024-07-13-unit_6_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  4703 Dec  6 12:38 2024-07-13-unit_7_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3684 Dec  6 12:38 2024-07-13-unit_8_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  2701 Dec  6 12:38 2024-07-13-unit_9_quiz.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1753 Dec  6 12:38 2024-07-14-unit_10_quiz.ipynb
#
# ./CSP:
# total 72
# -rw-r--r--   1 anishkasanghvi  staff   9184 Dec  6 12:38 2024-09-27-sprint2_plan.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  13862 Dec  6 12:38 2024-10-31-sprint3_plan.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   7831 Dec  6 12:38 2024-10-31-sprint4_plan.ipynb
# drwxr-xr-x   7 anishkasanghvi  staff    224 Dec  6 12:38 big-ideas
# drwxr-xr-x  15 anishkasanghvi  staff    480 Dec  6 12:38 flask
#
# ./CSP/big-ideas:
# total 0
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 big-idea-1
# drwxr-xr-x  4 anishkasanghvi  staff  128 Dec  6 12:38 big-idea-2
# drwxr-xr-x  8 anishkasanghvi  staff  256 Dec  6 12:38 big-idea-3-part-1-fundamentals
# drwxr-xr-x  6 anishkasanghvi  staff  192 Dec  6 12:38 big-idea-3-part-2-reinforce
# drwxr-xr-x  4 anishkasanghvi  staff  128 Dec  6 12:38 big-idea-4
#
# ./CSP/big-ideas/big-idea-1:
# total 24
# -rw-r--r--  1 anishkasanghvi  staff  8415 Dec  6 12:38 2023-10-04-big-idea-1_python-errors.ipynb
#
# ./CSP/big-ideas/big-idea-2:
# total 232
# -rw-r--r--  1 anishkasanghvi  staff  100550 Dec  6 12:38 2023-10-02-python_data-abstraction-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   13398 Dec  6 12:38 2023-10-02-python_data-abstraction-2.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals:
# total 0
# drwxr-xr-x  39 anishkasanghvi  staff  1248 Dec  6 12:38 Period1
# drwxr-xr-x  48 anishkasanghvi  staff  1536 Dec  6 12:38 Period2
# drwxr-xr-x  56 anishkasanghvi  staff  1792 Dec  6 12:38 Period3
# drwxr-xr-x  53 anishkasanghvi  staff  1696 Dec  6 12:38 Period4
# drwxr-xr-x  25 anishkasanghvi  staff   800 Dec  6 12:38 Period5
# drwxr-xr-x  12 anishkasanghvi  staff   384 Dec  6 12:38 Teacher
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period1:
# total 512
# -rw-r--r--   1 anishkasanghvi  staff   4637 Dec  6 12:38 2023-10-04-big-idea-3-fundamentals.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   5524 Dec  6 12:38 2024-09-24-3_1_1.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   4282 Dec  6 12:38 2024-09-24-3_1_2.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   6846 Dec  6 12:38 2024-09-24-3_1_3.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   5716 Dec  6 12:38 2024-09-24-3_1_4.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   5046 Dec  6 12:38 2024-09-24-3_1_5.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   6613 Dec  6 12:38 2024-09-24-3_1_6.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   5985 Dec  6 12:38 2024-09-24-3_1_7.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  13445 Dec  6 12:38 2024-09-24-3_1_lesson_popcorn.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   1303 Dec  6 12:38 2024-09-24-3_4.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   1985 Dec  6 12:38 2024-09-24-3_4_1.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2941 Dec  6 12:38 2024-09-24-3_4_10.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   5442 Dec  6 12:38 2024-09-24-3_4_11.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  17077 Dec  6 12:38 2024-09-24-3_4_1_python_strings.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2188 Dec  6 12:38 2024-09-24-3_4_2.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  13107 Dec  6 12:38 2024-09-24-3_4_2_js_strings.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2123 Dec  6 12:38 2024-09-24-3_4_3.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  12816 Dec  6 12:38 2024-09-24-3_4_3_python_hack.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2123 Dec  6 12:38 2024-09-24-3_4_4.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   9965 Dec  6 12:38 2024-09-24-3_4_4_js_hw_and_hack.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2016 Dec  6 12:38 2024-09-24-3_4_5.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2079 Dec  6 12:38 2024-09-24-3_4_6.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2047 Dec  6 12:38 2024-09-24-3_4_7.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2020 Dec  6 12:38 2024-09-24-3_4_8.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2954 Dec  6 12:38 2024-09-24-3_4_9.ipynb
# -rw-r--r--   1 anishkasanghvi  staff    661 Dec  6 12:38 2024-09-25-bigIdea-3-2.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  12440 Dec  6 12:38 2024-9-24-big-idea-3-8-Lesson.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   3600 Dec  6 12:38 2024-9-25-big-idea-3-3-hw.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   5679 Dec  6 12:38 2024-9-25-big-idea-3-3.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   4065 Dec  6 12:38 2024-9-25-big-idea-3-5-hw.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   7864 Dec  6 12:38 2024-9-25-big-idea-3-5.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2624 Dec  6 12:38 2024-9-25-big-idea-3-8-1.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   2225 Dec  6 12:38 2024-9-25-big-idea-3-8-2.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   4625 Dec  6 12:38 2024-9-25-big-idea-3-8-3.ipynb
# drwxr-xr-x   9 anishkasanghvi  staff    288 Dec  6 12:38 3.2_BigIdeas
# drwxr-xr-x  10 anishkasanghvi  staff    320 Dec  6 12:38 GMGZtable
# drwxr-xr-x   6 anishkasanghvi  staff    192 Dec  6 12:38 Lists
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period1/3.2_BigIdeas:
# total 96
# -rw-r--r--  1 anishkasanghvi  staff  3438 Dec  6 12:38 2024-01-24-3.2-home.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6380 Dec  6 12:38 2024-09-25-DT1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6190 Dec  6 12:38 2024-09-25-DT2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  7772 Dec  6 12:38 2024-09-25-DT3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6729 Dec  6 12:38 2024-09-25-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1476 Dec  6 12:38 2024-09-25-hw.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  7267 Dec  6 12:38 2024-09-25-json.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period1/GMGZtable:
# total 232
# -rw-r--r--  1 anishkasanghvi  staff  14111 Dec  6 12:38 2023-10-10-big-idea-3-6-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6843 Dec  6 12:38 2023-10-10-big-idea-3-6-lesson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  19464 Dec  6 12:38 2023-10-10-big-idea-3-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2640 Dec  6 12:38 2023-10-10-big-idea-3-6_solution.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5149 Dec  6 12:38 2023-10-10-big-ideas-3-7-answer.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14529 Dec  6 12:38 2023-10-11-big-idea-3-7-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13586 Dec  6 12:38 2023-10-11-big-idea-3-7-lesson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  26612 Dec  6 12:38 2023-10-11-big-idea-3-7.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period1/Lists:
# total 80
# -rw-r--r--  1 anishkasanghvi  staff  7864 Dec  6 12:38 2024-09-25-bigIdea3_10_brandon.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  8931 Dec  6 12:38 2024-09-25-bigIdea3_10_carson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  7494 Dec  6 12:38 2024-09-25-bigIdea3_10_jackson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  8471 Dec  6 12:38 2024-09-25-bigIdea3_10_manahil.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period2:
# total 864
# -rw-r--r--  1 anishkasanghvi  staff   4637 Dec  6 12:38 2023-10-04-big-idea-3-fundamentals.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9330 Dec  6 12:38 2024-09-27-big-idea-3-7-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2506 Dec  6 12:38 2024-09-27-big-idea-3-7-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7789 Dec  6 12:38 2024-10-02-big-idea-3-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5014 Dec  6 12:38 2024-10-02-big-idea-3-7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5497 Dec  6 12:38 2024-9-21-big-idea-3-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11680 Dec  6 12:38 2024-9-22-big-idea-3-1-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10639 Dec  6 12:38 2024-9-22-big-idea-3-1-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14750 Dec  6 12:38 2024-9-22-big-idea-3-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6562 Dec  6 12:38 2024-9-23-big-idea-3-2-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3519 Dec  6 12:38 2024-9-23-big-idea-3-2-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6942 Dec  6 12:38 2024-9-23-big-idea-3-2-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6897 Dec  6 12:38 2024-9-23-big-idea-3-2-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6404 Dec  6 12:38 2024-9-23-big-idea-3-2-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5504 Dec  6 12:38 2024-9-23-big-idea-3-2-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4566 Dec  6 12:38 2024-9-23-big-idea-3-2-7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5062 Dec  6 12:38 2024-9-23-big-idea-3-2-8.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3730 Dec  6 12:38 2024-9-23-big-idea-3-2-9.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9525 Dec  6 12:38 2024-9-25-big-idea-3-1-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4145 Dec  6 12:38 2024-9-25-big-idea-3-1-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7385 Dec  6 12:38 2024-9-25-big-idea-3-10-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8094 Dec  6 12:38 2024-9-25-big-idea-3-10-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11718 Dec  6 12:38 2024-9-25-big-idea-3-10-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3753 Dec  6 12:38 2024-9-25-big-idea-3-10-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  50240 Dec  6 12:38 2024-9-25-big-idea-3-3-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3930 Dec  6 12:38 2024-9-25-big-idea-3-3-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4446 Dec  6 12:38 2024-9-25-big-idea-3-3-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11826 Dec  6 12:38 2024-9-25-big-idea-3-3-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2898 Dec  6 12:38 2024-9-25-big-idea-3-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12805 Dec  6 12:38 2024-9-25-big-idea-3-4-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7612 Dec  6 12:38 2024-9-25-big-idea-3-4-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5990 Dec  6 12:38 2024-9-25-big-idea-3-4-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   1323 Dec  6 12:38 2024-9-25-big-idea-3-4-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   1200 Dec  6 12:38 2024-9-25-big-idea-3-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8079 Dec  6 12:38 2024-9-25-big-idea-3-5-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11944 Dec  6 12:38 2024-9-25-big-idea-3-5-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2875 Dec  6 12:38 2024-9-25-big-idea-3-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7878 Dec  6 12:38 2024-9-25-big-idea-3-8-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10477 Dec  6 12:38 2024-9-25-big-idea-3-8-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7614 Dec  6 12:38 2024-9-25-big-idea-3-8-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10051 Dec  6 12:38 2024-9-25-big-idea-3-8-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8065 Dec  6 12:38 2024-9-26-big-idea-3-5-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6216 Dec  6 12:38 2024-9-26-big-idea-3-5-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8147 Dec  6 12:38 2024-9-27-big-idea-3-10.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6157 Dec  6 12:38 2024-9-27-big-idea-3-6-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8738 Dec  6 12:38 2024-9-27-big-idea-3-6-2.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period3:
# total 1240
# -rw-r--r--  1 anishkasanghvi  staff  16795 Dec  6 12:38 2023-10-04-big-idea-3-fundamentals.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5698 Dec  6 12:38 2024-09-23-fundamentals-3-1-0.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  17071 Dec  6 12:38 2024-09-23-fundamentals-3-1-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7132 Dec  6 12:38 2024-09-23-fundamentals-3-1-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10001 Dec  6 12:38 2024-09-23-fundamentals-3-1-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6785 Dec  6 12:38 2024-09-23-fundamentals-3-1-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9070 Dec  6 12:38 2024-09-23-fundamentals-3-1-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8468 Dec  6 12:38 2024-09-25-fundamentals-3-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6983 Dec  6 12:38 2024-09-25-fundamentals-3-3-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7036 Dec  6 12:38 2024-09-25-fundamentals-3-3-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8409 Dec  6 12:38 2024-09-25-fundamentals-3-3-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5904 Dec  6 12:38 2024-09-25-fundamentals-3-3-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6628 Dec  6 12:38 2024-09-25-fundamentals-3-3-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11873 Dec  6 12:38 2024-09-25-fundamentals-3-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7024 Dec  6 12:38 2024-09-25-fundamentals-3-4-0.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  15068 Dec  6 12:38 2024-09-25-fundamentals-3-4-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6360 Dec  6 12:38 2024-09-25-fundamentals-3-4-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  21687 Dec  6 12:38 2024-09-25-fundamentals-3-4-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7465 Dec  6 12:38 2024-09-25-fundamentals-3-4-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9397 Dec  6 12:38 2024-09-25-fundamentals-3-4-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10554 Dec  6 12:38 2024-09-25-fundamentals-3-5-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7549 Dec  6 12:38 2024-09-25-fundamentals-3-5-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10302 Dec  6 12:38 2024-09-25-fundamentals-3-5-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7794 Dec  6 12:38 2024-09-25-fundamentals-3-5-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11707 Dec  6 12:38 2024-09-25-fundamentals-3-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10359 Dec  6 12:38 2024-09-25-fundamentals-3-8-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9273 Dec  6 12:38 2024-09-26-fundamentals-3-8-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8588 Dec  6 12:38 2024-09-26-fundamentals-3-8-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8909 Dec  6 12:38 2024-09-26-fundamentals-3-8-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11577 Dec  6 12:38 2024-09-26-fundamentals-3-8-7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10450 Dec  6 12:38 2024-09-26-fundamentals-3-8-8.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  17465 Dec  6 12:38 2024-09-27-fundamentals-3-2-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  16895 Dec  6 12:38 2024-09-27-fundamentals-3-2-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12894 Dec  6 12:38 2024-09-27-fundamentals-3-2-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  16453 Dec  6 12:38 2024-09-27-fundamentals-3-8-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   1936 Dec  6 12:38 2024-10-03-fundamentals-3-10-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6395 Dec  6 12:38 2024-10-04-fundamentals-3-10-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6181 Dec  6 12:38 2024-10-2-fundamentals-3-6-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6899 Dec  6 12:38 2024-10-2-fundamentals-3-6-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6467 Dec  6 12:38 2024-10-2-fundamentals-3-6-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8336 Dec  6 12:38 2024-10-2-fundamentals-3-6-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6576 Dec  6 12:38 2024-10-2-fundamentals-3.7.1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7013 Dec  6 12:38 2024-10-2-fundamentals-3.7.2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9879 Dec  6 12:38 2024-10-2-fundamentals-3.7.3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  16091 Dec  6 12:38 2024-10-2-fundamentals-3.7.4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5899 Dec  6 12:38 2024-10-2-fundamentals-3.7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5653 Dec  6 12:38 2024-10-2-fundametals-3-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9496 Dec  6 12:38 2024-10-25-fundamentals-3-10-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8786 Dec  6 12:38 2024-10-25-fundamentals-3-10-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3109 Dec  6 12:38 2024-10-25-fundamentals-3-10-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14261 Dec  6 12:38 2024-10-25-fundamentals-3-10.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14311 Dec  6 12:38 2024-10-3-fundamentals-3-8-9.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14696 Dec  6 12:38 2024-9-25-fundamentals-3-8-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff    136 Dec  6 12:38 data.json
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period4:
# total 1232
# -rw-r--r--  1 anishkasanghvi  staff   6678 Dec  6 12:38 2023-10-04-big-idea-3-fundamentals.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6660 Dec  6 12:38 2024-09-25-big-idea-3-4-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10240 Dec  6 12:38 2024-09-25-big-idea-3-6-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13188 Dec  6 12:38 2024-09-25-big-idea-3-6-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3192 Dec  6 12:38 2024-09-25-big-idea-3-6-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3584 Dec  6 12:38 2024-09-25-big-idea-3-6-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9063 Dec  6 12:38 2024-09-25-big-idea-3-7-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4730 Dec  6 12:38 2024-09-25-big-idea-3-8-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5484 Dec  6 12:38 2024-09-25-big-idea-3-8-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4062 Dec  6 12:38 2024-09-25-big-idea-3-8-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6950 Dec  6 12:38 2024-09-25-big-idea-3-8-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13692 Dec  6 12:38 2024-09-26-big-idea-3-10A.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11028 Dec  6 12:38 2024-09-26-big-idea-3-7-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5689 Dec  6 12:38 2024-09-26-big-idea-3-7-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6142 Dec  6 12:38 2024-09-26-big-idea-3-7-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  26199 Dec  6 12:38 2024-09-26-big-idea-3-8-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  18122 Dec  6 12:38 2024-09-27-fundamentals-3-10B-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14805 Dec  6 12:38 2024-09-27-fundamentals-3-10B-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4841 Dec  6 12:38 2024-09-27-fundamentals-3-10B-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4509 Dec  6 12:38 2024-09-27-fundamentals-3-10B-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11662 Dec  6 12:38 2024-09-29-big-idea-3-1-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  22158 Dec  6 12:38 2024-09-29-big-idea-3-1-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12669 Dec  6 12:38 2024-09-29-big-idea-3-1-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5625 Dec  6 12:38 2024-09-29-big-idea-3-4-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6388 Dec  6 12:38 2024-09-29-big-idea-3-4-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3592 Dec  6 12:38 2024-09-29-big-idea-3-4-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   1400 Dec  6 12:38 2024-09-30-big-idea-3-10A..ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8954 Dec  6 12:38 2024-09-30-big-idea-3-10A.1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8296 Dec  6 12:38 2024-09-30-big-idea-3-10A.2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6007 Dec  6 12:38 2024-09-30-big-idea-3-10A.3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6408 Dec  6 12:38 2024-09-30-big-idea-3-10A.4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7260 Dec  6 12:38 2024-9-22-big-idea-3-1-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  18318 Dec  6 12:38 2024-9-22-big-idea-3-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4728 Dec  6 12:38 2024-9-24-big-idea-3-2-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4745 Dec  6 12:38 2024-9-24-big-idea-3-2-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6536 Dec  6 12:38 2024-9-24-big-idea-3-2-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7807 Dec  6 12:38 2024-9-24-big-idea-3-2-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6558 Dec  6 12:38 2024-9-24-big-idea-3-2-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7485 Dec  6 12:38 2024-9-24-big-idea-3-2-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9194 Dec  6 12:38 2024-9-24-big-idea-3-2-7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5803 Dec  6 12:38 2024-9-24-big-idea-3-2-8.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4529 Dec  6 12:38 2024-9-24-big-idea-3-2-9.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  47886 Dec  6 12:38 2024-9-24-big-idea-3-3-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  46607 Dec  6 12:38 2024-9-24-big-idea-3-3-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8921 Dec  6 12:38 2024-9-24-big-idea-3-3-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4008 Dec  6 12:38 2024-9-24-big-idea-3-3-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2419 Dec  6 12:38 2024-9-24-big-idea-3-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  17615 Dec  6 12:38 2024-9-24-big-idea-3-5-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  15204 Dec  6 12:38 2024-9-24-big-idea-3-5-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  16468 Dec  6 12:38 2024-9-24-big-idea-3-5-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4584 Dec  6 12:38 2024-9-24-big-idea-3-5-4.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Period5:
# total 352
# -rw-r--r--  1 anishkasanghvi  staff   4606 Dec  6 12:38 2024-09-22-big-idea-3-fundamentals.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4032 Dec  6 12:38 2024-09-23-3.1-objectives.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3229 Dec  6 12:38 2024-09-24-3.1-py-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10053 Dec  6 12:38 2024-09-24-3.1.1-py.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10461 Dec  6 12:38 2024-09-24-3.1.3-js.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3131 Dec  6 12:38 2024-09-24-3.1.4-js-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3331 Dec  6 12:38 2024-09-24-3.4-A-objectives.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11321 Dec  6 12:38 2024-09-24-3.4-B1-py-strings.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2422 Dec  6 12:38 2024-09-24-3.4-B2-py-strings-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8133 Dec  6 12:38 2024-09-24-3.4-C1-js-strings.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2379 Dec  6 12:38 2024-09-24-3.4-C2-js-strings-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5064 Dec  6 12:38 2024-09-24-bigIdea-3-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2768 Dec  6 12:38 2024-09-25-3.3.1_mathematicalOperations.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3854 Dec  6 12:38 2024-09-25-3.3.2_hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2731 Dec  6 12:38 2024-09-25-3.3.3_homework.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4512 Dec  6 12:38 2024-09-25-big-idea-3-6-part-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6140 Dec  6 12:38 2024-09-25-big-idea-3-6-part-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10250 Dec  6 12:38 2024-09-25-big-idea-3-7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   6904 Dec  6 12:38 2024-09-25-js-hw.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13723 Dec  6 12:38 2024-09-25-json.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10833 Dec  6 12:38 2024-09-25-variables.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4035 Dec  6 12:38 2024-09-26-3.5.1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8717 Dec  6 12:38 2024-09-26-3.5.2.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-1-fundamentals/Teacher:
# total 304
# -rw-r--r--  1 anishkasanghvi  staff   4647 Dec  6 12:38 2023-10-04-big-idea-3-fundamentals.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11462 Dec  6 12:38 2023-10-05-big-idea-3-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  18277 Dec  6 12:38 2023-10-05-big-idea-3-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  48623 Dec  6 12:38 2023-10-05-big-idea-3-3.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4959 Dec  6 12:38 2023-10-05-big-idea-3-4.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4470 Dec  6 12:38 2023-10-10-big-idea-3-5.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7767 Dec  6 12:38 2023-10-10-big-idea-3-6.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7602 Dec  6 12:38 2023-10-11-big-idea-3-7.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14573 Dec  6 12:38 2023-10-12-big-idea-3-8.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12680 Dec  6 12:38 2023-10-19-big-idea-3-10.ipynb
#
# ./CSP/big-ideas/big-idea-3-part-2-reinforce:
# total 112
# -rw-r--r--  1 anishkasanghvi  staff   9854 Dec  6 12:38 2023-10-28-big-idea-3_Iteration.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13096 Dec  6 12:38 2023-10-28-big-idea-3_python-lists.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14581 Dec  6 12:38 2023-10-29-big-idea-3_algorithms.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10278 Dec  6 12:38 2023-10-30-big-idea-3_developing-procedures.ipynb
#
# ./CSP/big-ideas/big-idea-4:
# total 72
# -rw-r--r--  1 anishkasanghvi  staff  10614 Dec  6 12:38 2024-12-02-python-flask_in_jupyter.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  22318 Dec  6 12:38 2024-12-03-aws-deployment.ipynb
#
# ./CSP/flask:
# total 680
# -rw-r--r--  1 anishkasanghvi  staff  12882 Dec  6 12:38 2023-10-22-flask-debug-walk.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  33889 Dec  6 12:38 2023-10-29-flocker_api.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  15923 Dec  6 12:38 2023-10-29-flocker_post.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5997 Dec  6 12:38 2024-01-24-flask-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8876 Dec  6 12:38 2024-01-25-flask-anatomy.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  89001 Dec  6 12:38 2024-01-25-flask-code-full_stack.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  49612 Dec  6 12:38 2024-01-25-flask-code-ideation.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  26212 Dec  6 12:38 2024-01-25-flask-code-login-page.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14682 Dec  6 12:38 2024-01-25-flask-code-sign-up.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  22339 Dec  6 12:38 2024-01-25-flask-code-style.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13216 Dec  6 12:38 2024-01-25-flask-play-in-jupyter.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2248 Dec  6 12:38 2024-01-26-flask-scrum.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  22289 Dec  6 12:38 2024-01-27-flask-deploy-aws.ipynb
#
# ./CSSE:
# total 216
# -rw-r--r--   1 anishkasanghvi  staff  24224 Dec  6 12:38 2023-12-07-CSSE-platform_student.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  11146 Dec  6 12:38 2023-12-10-CSSE-parallax_student.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  10855 Dec  6 12:38 2023-12-11-CSSE-student_animation.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  20900 Dec  6 12:38 2023-12-13-CSSE-student_Selection_LocalStorage.ipynb
# -rw-r--r--   1 anishkasanghvi  staff  12565 Dec  6 12:38 2023-12-14-CSSE_student_leaderboard.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   3847 Dec  6 12:38 2024-10-09-sprint2_plan.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   8867 Dec  6 12:38 2024-11-04-sprint3_plan.ipynb
# -rw-r--r--   1 anishkasanghvi  staff   3404 Dec  6 12:38 2024-11-18-sprint4_plan.ipynb
# drwxr-xr-x   8 anishkasanghvi  staff    256 Dec  6 12:38 A-Game-Intro-RPG
# drwxr-xr-x  13 anishkasanghvi  staff    416 Dec  6 12:38 Lessons
# drwxr-xr-x   3 anishkasanghvi  staff     96 Dec  6 12:38 javascript
# drwxr-xr-x   8 anishkasanghvi  staff    256 Dec  6 12:38 mario
#
# ./CSSE/A-Game-Intro-RPG:
# total 128
# -rw-r--r--  1 anishkasanghvi  staff   4549 Dec  6 12:38 2023-09-20-game_animations-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  14802 Dec  6 12:38 2023-09-21-game_animations-anatomy.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5898 Dec  6 12:38 2023-09-21-game_animations-json-object.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5268 Dec  6 12:38 2023-09-22-game_animations-background.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10791 Dec  6 12:38 2023-09-22-game_animations-player.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9952 Dec  6 12:38 2023-09-26-game_animations-hacks.ipynb
#
# ./CSSE/Lessons:
# total 16
# -rw-r--r--  1 anishkasanghvi  staff  4509 Dec  6 12:38 2024-11-09-sprint3_lessons.ipynb
# drwxr-xr-x  4 anishkasanghvi  staff   128 Dec  6 12:38 Arrays
# drwxr-xr-x  6 anishkasanghvi  staff   192 Dec  6 12:38 Booleans
# drwxr-xr-x  6 anishkasanghvi  staff   192 Dec  6 12:38 Classes_and_Methods
# drwxr-xr-x  6 anishkasanghvi  staff   192 Dec  6 12:38 Conditions
# drwxr-xr-x  5 anishkasanghvi  staff   160 Dec  6 12:38 Data_Abstractions
# drwxr-xr-x  6 anishkasanghvi  staff   192 Dec  6 12:38 Iteration
# drwxr-xr-x  8 anishkasanghvi  staff   256 Dec  6 12:38 Mathematic_Expressions
# drwxr-xr-x  5 anishkasanghvi  staff   160 Dec  6 12:38 Nested_Conditionals
# drwxr-xr-x  5 anishkasanghvi  staff   160 Dec  6 12:38 Strings
# drwxr-xr-x  5 anishkasanghvi  staff   160 Dec  6 12:38 Variables
#
# ./CSSE/Lessons/Arrays:
# total 40
# -rw-r--r--  1 anishkasanghvi  staff  9495 Dec  6 12:38 2024-11-15-accessing-and-deleting-elements.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  7883 Dec  6 12:38 2024-11-15-lists_presentation_3.ipynb
#
# ./CSSE/Lessons/Booleans:
# total 56
# -rw-r--r--  1 anishkasanghvi  staff  4169 Dec  6 12:38 10-24BOOLEANSHW.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5768 Dec  6 12:38 2024-10-25-booleanslesson.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  2164 Dec  6 12:38 2024-10-31-booleans-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  7545 Dec  6 12:38 2024-10-31-booleans-p2.ipynb
#
# ./CSSE/Lessons/Classes_and_Methods:
# total 96
# -rw-r--r--  1 anishkasanghvi  staff  10520 Dec  6 12:38 2024-10-27-classes-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   9126 Dec  6 12:38 2024-10-27-classes-methods-in-depth.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7948 Dec  6 12:38 2024-11-04-classes-hw.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13623 Dec  6 12:38 2024-11-04-classes-static-keyword.ipynb
#
# ./CSSE/Lessons/Conditions:
# total 72
# -rw-r--r--  1 anishkasanghvi  staff   6512 Dec  6 12:38 2024-11-10-conditionals-hacks.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7649 Dec  6 12:38 2024-11-10-conditionals-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11148 Dec  6 12:38 2024-11-10-conditionals-p2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7086 Dec  6 12:38 2024-11-10-conditionals-p3.ipynb
#
# ./CSSE/Lessons/Data_Abstractions:
# total 88
# -rw-r--r--  1 anishkasanghvi  staff   6395 Dec  6 12:38 2024-11-06-data_abstraction-homework.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  24766 Dec  6 12:38 2024-11-06-data_abstraction-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   5507 Dec  6 12:38 2024-11-06-data_abstraction-popcornhacks.ipynb
#
# ./CSSE/Lessons/Iteration:
# total 56
# -rw-r--r--  1 anishkasanghvi  staff  3021 Dec  6 12:38 2024-11-2-iteration-homework.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  4256 Dec  6 12:38 2024-11-2-iteration-p1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5252 Dec  6 12:38 2024-11-5-iteration-p2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  5671 Dec  6 12:38 2024-11-7-Iteration-P3.ipynb
#
# ./CSSE/Lessons/Mathematic_Expressions:
# total 104
# -rw-r--r--  1 anishkasanghvi  staff  10075 Dec  6 12:38 2024-10-31-impliment_in_rpg.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3382 Dec  6 12:38 2024-10-31-math-expression-hw.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8948 Dec  6 12:38 2024-10-31-math-expression-p1-operators.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10154 Dec  6 12:38 2024-10-31-math-expression-p2-battle.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3285 Dec  6 12:38 2024-10-31-mathhomework.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7552 Dec  6 12:38 2024-10-31-operators.ipynb
#
# ./CSSE/Lessons/Nested_Conditionals:
# total 48
# -rw-r--r--  1 anishkasanghvi  staff   3364 Dec  6 12:38 2024-10-26-nested_conditionals-hw.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11192 Dec  6 12:38 2024-10-26-nested_conditionals-p1-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7807 Dec  6 12:38 2024-10-26-nested_conditionals-p2.ipynb
#
# ./CSSE/Lessons/Strings:
# total 40
# -rw-r--r--  1 anishkasanghvi  staff  5692 Dec  6 12:38 2024-10-30-strings-lesson-4-1.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  6804 Dec  6 12:38 2024-10-30-strings-lesson-4-2.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  2204 Dec  6 12:38 2024-10-30-strings-lesson-4-3.ipynb
#
# ./CSSE/Lessons/Variables:
# total 48
# -rw-r--r--  1 anishkasanghvi  staff  16375 Dec  6 12:38 2024-10-25-variables.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2596 Dec  6 12:38 2024-10-28-variables_hw.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2531 Dec  6 12:38 2024-10-29-variables_popcorn_hax.ipynb
#
# ./CSSE/javascript:
# total 0
# drwxr-xr-x  6 anishkasanghvi  staff  192 Dec  6 12:38 fundamentals
#
# ./CSSE/javascript/fundamentals:
# total 168
# -rw-r--r--  1 anishkasanghvi  staff  26089 Dec  6 12:38 2024-09-30-data-types-operations.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  39271 Dec  6 12:38 2024-09-30-for_sprites.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12718 Dec  6 12:38 2024-09-30-variables_IO.ipynb
# drwxr-xr-x  4 anishkasanghvi  staff    128 Dec  6 12:38 images
#
# ./CSSE/javascript/fundamentals/images:
# total 7752
# -rwxr-xr-x  1 anishkasanghvi  staff  3851947 Dec  6 12:38 mario.png
# -rw-r--r--  1 anishkasanghvi  staff   113410 Dec  6 12:38 tux.png
#
# ./CSSE/mario:
# total 0
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 _intro
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 background
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 enemy
# drwxr-xr-x  4 anishkasanghvi  staff  128 Dec  6 12:38 obstacles
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 platform
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 player
#
# ./CSSE/mario/_intro:
# total 8
# -rw-r--r--  1 anishkasanghvi  staff  3582 Dec  6 12:38 2023-07-30-game_mario-intro.ipynb
#
# ./CSSE/mario/background:
# total 64
# -rw-r--r--  1 anishkasanghvi  staff  30574 Dec  6 12:38 2023-08-06-mario_background.ipynb
#
# ./CSSE/mario/enemy:
# total 56
# -rw-r--r--  1 anishkasanghvi  staff  26469 Dec  6 12:38 2023-08-05-mario_goomba.ipynb
#
# ./CSSE/mario/obstacles:
# total 104
# -rw-r--r--  1 anishkasanghvi  staff  22616 Dec  6 12:38 2023-08-03-mario_tube.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  25783 Dec  6 12:38 2023-08-04-mario_block.ipynb
#
# ./CSSE/mario/platform:
# total 32
# -rw-r--r--  1 anishkasanghvi  staff  14791 Dec  6 12:38 2023-08-02-mario_platform.ipynb
#
# ./CSSE/mario/player:
# total 24
# -rw-r--r--  1 anishkasanghvi  staff  10618 Dec  6 12:38 2023-08-01-mario_player.ipynb
#
# ./Foundation:
# total 8
# -rw-r--r--   1 anishkasanghvi  staff  3974 Dec  6 12:38 2024-08-21-sprint1_plan.ipynb
# drwxr-xr-x   5 anishkasanghvi  staff   160 Dec  6 12:38 A-pair_programming
# drwxr-xr-x   8 anishkasanghvi  staff   256 Dec  6 12:38 B-tools_and_equipment
# drwxr-xr-x   8 anishkasanghvi  staff   256 Dec  6 12:38 C-github_pages
# drwxr-xr-x   6 anishkasanghvi  staff   192 Dec  6 12:38 D-sass_basics
# drwxr-xr-x  10 anishkasanghvi  staff   320 Dec  6 12:38 E-frontend_development
# drwxr-xr-x   3 anishkasanghvi  staff    96 Dec  6 12:38 F-projects
#
# ./Foundation/A-pair_programming:
# total 48
# -rw-r--r--  1 anishkasanghvi  staff   5433 Dec  6 12:38 2023-08-16-pair_programming.md
# -rw-r--r--  1 anishkasanghvi  staff   3918 Dec  6 12:38 2023-08-16-pair_showcase.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11624 Dec  6 12:38 2023-08-17-pair_habits.ipynb
#
# ./Foundation/B-tools_and_equipment:
# total 464
# -rw-r--r--  1 anishkasanghvi  staff    9767 Dec  6 12:38 2023-08-19-devops_accounts.ipynb
# -rw-r--r--  1 anishkasanghvi  staff    5931 Dec  6 12:38 2023-08-21-devops_tools-home.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   23630 Dec  6 12:38 2023-08-21-devops_tools-setup.ipynb
# -rw-r--r--@ 1 anishkasanghvi  staff  143973 Dec 11 11:52 2023-08-22-devops_tools-verify.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   32288 Dec  6 12:38 2023-08-23-devops-githhub_pages-play.ipynb
# -rw-r--r--  1 anishkasanghvi  staff    9479 Dec  6 12:38 2023-08-23-devops-hacks.ipynb
#
# ./Foundation/C-github_pages:
# total 128
# -rw-r--r--  1 anishkasanghvi  staff  14719 Dec  6 12:38 2023-08-23-github_pages-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12484 Dec  6 12:38 2023-08-23-github_pages-markdonwn.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10111 Dec  6 12:38 2023-08-24-github_pages-anatomy.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3850 Dec  6 12:38 2023-08-25-github_pages-utterances.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  10291 Dec  6 12:38 2023-08-26-github-pages-jekyll.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   2149 Dec  6 12:38 2023-08-27-github-pages-hacks.ipynb
#
# ./Foundation/D-sass_basics:
# total 112
# -rw-r--r--  1 anishkasanghvi  staff  12586 Dec  6 12:38 2023-09-01-SASS-basics-play.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  11648 Dec  6 12:38 2023-09-01-SASS_basics-intro.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  13865 Dec  6 12:38 2023-09-02-SASS_basics-coding.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   8415 Dec  6 12:38 2024-07-20-SASS-hacks.ipynb
#
# ./Foundation/E-frontend_development:
# total 248
# -rw-r--r--  1 anishkasanghvi  staff   6951 Dec  6 12:38 2023-08-27-frontend-basics-playground.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7054 Dec  6 12:38 2023-08-28-frontend-basics-html.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   7204 Dec  6 12:38 2023-08-28-frontend-basics-js-errors.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  16924 Dec  6 12:38 2023-08-29-frontend-basics-of-js.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  20154 Dec  6 12:38 2023-08-30-frontend-basics-js-data-types.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12454 Dec  6 12:38 2023-08-30-frontend-basics-js-with-html.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  12781 Dec  6 12:38 2023-08-30-frontend-input.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  25250 Dec  6 12:38 2023-08-30-frontend-output_objects.ipynb
#
# ./Foundation/F-projects:
# total 16
# -rw-r--r--  1 anishkasanghvi  staff  7062 Dec  6 12:38 2023-08-30-javascript_project-play.ipynb
#
# ./KASM:
# total 0
# drwxr-xr-x  8 anishkasanghvi  staff  256 Dec  6 12:38 Config_Guides
# drwxr-xr-x  5 anishkasanghvi  staff  160 Dec  6 12:38 Database
# drwxr-xr-x  5 anishkasanghvi  staff  160 Dec  6 12:38 MultiServer
# drwxr-xr-x  3 anishkasanghvi  staff   96 Dec  6 12:38 User_Guide
# drwxr-xr-x  5 anishkasanghvi  staff  160 Dec  6 12:38 Workspaces
#
# ./KASM/Config_Guides:
# total 56
# -rw-r--r--  1 anishkasanghvi  staff  4804 Dec  6 12:38 2024-07-05-docker-cronjob-for-containers.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3646 Dec  6 12:38 2024-07-05-manual-addition-of-docker-images.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1183 Dec  6 12:38 2024-07-12-security-group-configuration.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3222 Dec  6 12:38 2024-07-15-manual-registry-addition.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  2088 Dec  6 12:38 2024-07-15-persistent-data.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  2292 Dec  6 12:38 2024-07-31-plans-for-big-meet.ipynb
#
# ./KASM/Database:
# total 88
# -rw-r--r--  1 anishkasanghvi  staff  11567 Dec  6 12:38 2024-08-10-rds-documentation.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   4665 Dec  6 12:38 2024-08-14-migration.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  23557 Dec  6 12:38 2024-08-14-python-api-4-kasm.ipynb
#
# ./KASM/MultiServer:
# total 56
# -rw-r--r--  1 anishkasanghvi  staff  18056 Dec  6 12:38 2024-07-30-autoscale-config.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3663 Dec  6 12:38 2024-08-07-persistent-storage.ipynb
# -rw-r--r--  1 anishkasanghvi  staff   3473 Dec  6 12:38 2024-08-14-workspace-registry-admin.ipynb
#
# ./KASM/User_Guide:
# total 32
# -rw-r--r--  1 anishkasanghvi  staff  12450 Dec  6 12:38 2024-11-17-user-kasm.ipynb
#
# ./KASM/Workspaces:
# total 40
# -rw-r--r--  1 anishkasanghvi  staff  8672 Dec  6 12:38 2024-08-14-container-building.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  1285 Dec  6 12:38 2024-08-14-dockerhub-push.ipynb
# -rw-r--r--  1 anishkasanghvi  staff  3038 Dec  6 12:38 2024-08-14-nighthawk-registry.ipynb

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Look for images, print working directory, list files"
# cd $project/images  # this should exist per fastpages
# pwd
# ls -lR
# Out:
# Look for images, print working directory, list files
# /Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka/images
# total 27680
# -rw-r--r--   1 anishkasanghvi  staff  3827903 Dec  6 12:38 Prof._Stampfers_Stroboscopische_Scheibe_No._X.gif
# drwxr-xr-x  15 anishkasanghvi  staff      480 Dec  6 12:38 about
# -rw-r--r--   1 anishkasanghvi  staff   129584 Dec  6 12:38 agile.webp
# drwxr-xr-x  26 anishkasanghvi  staff      832 Dec  6 12:38 binary
# drwxr-xr-x  10 anishkasanghvi  staff      320 Dec  6 12:38 course-brag
# -rw-r--r--   1 anishkasanghvi  staff   134051 Dec  6 12:38 createusersample.png
# drwxr-xr-x   5 anishkasanghvi  staff      160 Dec  6 12:38 csp-period-5-flowcharts
# -rw-r--r--   1 anishkasanghvi  staff    15406 Dec  6 12:38 favicon.ico
# -rw-r--r--   1 anishkasanghvi  staff   177895 Dec  6 12:38 food.png
# drwxr-xr-x   5 anishkasanghvi  staff      160 Dec  6 12:38 fullstack
# -rw-r--r--   1 anishkasanghvi  staff   244133 Dec  6 12:38 homesample.png
# -rw-r--r--   1 anishkasanghvi  staff    22763 Dec  6 12:38 image_matrix.png
# -rw-r--r--   1 anishkasanghvi  staff   220573 Dec  6 12:38 information.png
# drwxr-xr-x   5 anishkasanghvi  staff      160 Dec  6 12:38 jokes
# -rw-r--r--   1 anishkasanghvi  staff   118483 Dec  6 12:38 jokes.png
# drwxr-xr-x  13 anishkasanghvi  staff      416 Dec  6 12:38 jpa-lesson-images
# drwxr-xr-x   9 anishkasanghvi  staff      288 Dec  6 12:38 kasm
# -rw-r--r--   1 anishkasanghvi  staff   155071 Dec  6 12:38 loginesample.png
# -rw-r--r--   1 anishkasanghvi  staff    34239 Dec  6 12:38 logo.png
# -rwxr-xr-x   1 anishkasanghvi  staff  3851947 Dec  6 12:38 mario.png
# -rwxr-xr-x   1 anishkasanghvi  staff  3851947 Dec  6 12:38 mario_animation.png
# drwxr-xr-x   4 anishkasanghvi  staff      128 Dec  6 12:38 nitd_rpg
# drwxr-xr-x   3 anishkasanghvi  staff       96 Dec  6 12:38 notebooks
# drwxr-xr-x  13 anishkasanghvi  staff      416 Dec  6 12:38 p1group1images
# drwxr-xr-x  11 anishkasanghvi  staff      352 Dec  6 12:38 platformer
# -rw-r--r--   1 anishkasanghvi  staff   126947 Dec  6 12:38 post_form.png
# -rw-r--r--   1 anishkasanghvi  staff   165794 Dec  6 12:38 postmanexample.png
# -rw-r--r--   1 anishkasanghvi  staff    81516 Dec  6 12:38 prime_numbers.jpg
# drwxr-xr-x   5 anishkasanghvi  staff      160 Dec  6 12:38 rpg
# -rw-r--r--   1 anishkasanghvi  staff   207818 Dec  6 12:38 sleep.png
# -rw-r--r--   1 anishkasanghvi  staff   203861 Dec  6 12:38 stress.png
# -rw-r--r--   1 anishkasanghvi  staff   168467 Dec  6 12:38 tracker1.png
# -rw-r--r--   1 anishkasanghvi  staff   113410 Dec  6 12:38 tux.png
# drwxr-xr-x   4 anishkasanghvi  staff      128 Dec  6 12:38 u8-p1-assets
# -rw-r--r--   1 anishkasanghvi  staff    27510 Dec  6 12:38 user_management_db.png
# -rw-r--r--   1 anishkasanghvi  staff   244703 Dec  6 12:38 waterfood.png
# -rw-r--r--   1 anishkasanghvi  staff    12911 Dec  6 12:38 wireframe.png
#
# ./about:
# total 44576
# -rw-r--r--  1 anishkasanghvi  staff  1209495 Dec  6 12:38 claire.jpg
# -rw-r--r--  1 anishkasanghvi  staff  1066028 Dec  6 12:38 familytree.png
# -rw-r--r--  1 anishkasanghvi  staff  3515847 Dec  6 12:38 farm.jpg
# -rw-r--r--  1 anishkasanghvi  staff  1808240 Dec  6 12:38 grandkids.jpg
# -rw-r--r--  1 anishkasanghvi  staff   541550 Dec  6 12:38 john_lora.jpg
# -rw-r--r--  1 anishkasanghvi  staff   358139 Dec  6 12:38 john_tamara.jpg
# -rw-r--r--  1 anishkasanghvi  staff  1370370 Dec  6 12:38 lora_fam.jpg
# -rw-r--r--  1 anishkasanghvi  staff   898485 Dec  6 12:38 lora_fam2.jpg
# -rw-r--r--  1 anishkasanghvi  staff    39644 Dec  6 12:38 missionary.jpg
# -rw-r--r--  1 anishkasanghvi  staff   935627 Dec  6 12:38 pj_party.jpg
# -rw-r--r--  1 anishkasanghvi  staff   392609 Dec  6 12:38 surf.jpg
# -rw-r--r--  1 anishkasanghvi  staff  2288602 Dec  6 12:38 tamara_fam.jpg
# -rw-r--r--  1 anishkasanghvi  staff  8368940 Dec  6 12:38 trent_family.png
#
# ./binary:
# total 10080
# -rw-r--r--  1 anishkasanghvi  staff   37088 Dec  6 12:38 1.png
# -rw-r--r--  1 anishkasanghvi  staff   39155 Dec  6 12:38 2.png
# -rw-r--r--  1 anishkasanghvi  staff  145986 Dec  6 12:38 andgate.png
# -rw-r--r--  1 anishkasanghvi  staff  221394 Dec  6 12:38 ascii_label.png
# -rw-r--r--  1 anishkasanghvi  staff   82759 Dec  6 12:38 b.png
# -rw-r--r--  1 anishkasanghvi  staff  322245 Dec  6 12:38 binary_math_conversion.png
# -rw-r--r--  1 anishkasanghvi  staff  298587 Dec  6 12:38 binary_shift.png
# -rw-r--r--  1 anishkasanghvi  staff   19526 Dec  6 12:38 codetable.png
# -rw-r--r--  1 anishkasanghvi  staff   82392 Dec  6 12:38 color_block.png
# -rw-r--r--  1 anishkasanghvi  staff  457749 Dec  6 12:38 color_code.png
# -rw-r--r--  1 anishkasanghvi  staff  301661 Dec  6 12:38 elaboration_of_shift.png
# -rw-r--r--  1 anishkasanghvi  staff   30647 Dec  6 12:38 halt.png
# -rw-r--r--  1 anishkasanghvi  staff  121894 Dec  6 12:38 integer_math_neg.png
# -rw-r--r--  1 anishkasanghvi  staff  125395 Dec  6 12:38 integer_math_pos.png
# -rw-r--r--  1 anishkasanghvi  staff  419775 Dec  6 12:38 logic_gate_application.png
# -rw-r--r--  1 anishkasanghvi  staff  536361 Dec  6 12:38 logic_gate_lab.png
# -rw-r--r--  1 anishkasanghvi  staff  107742 Dec  6 12:38 logic_gates.png
# -rw-r--r--  1 anishkasanghvi  staff  888227 Dec  6 12:38 logic_of_shift.png
# -rw-r--r--  1 anishkasanghvi  staff   17921 Dec  6 12:38 problems.png
# -rw-r--r--  1 anishkasanghvi  staff   38846 Dec  6 12:38 reverse.png
# -rw-r--r--  1 anishkasanghvi  staff  373203 Dec  6 12:38 sample_unicode.png
# -rw-r--r--  1 anishkasanghvi  staff  145986 Dec  6 12:38 truth.png
# -rw-r--r--  1 anishkasanghvi  staff  245559 Dec  6 12:38 twos_complement.png
# -rw-r--r--  1 anishkasanghvi  staff   55105 Dec  6 12:38 unsigned_addition.png
#
# ./course-brag:
# total 6248
# -rw-r--r--  1 anishkasanghvi  staff  536162 Dec  6 12:38 ccr.png
# -rw-r--r--  1 anishkasanghvi  staff  654211 Dec  6 12:38 csa.png
# -rw-r--r--  1 anishkasanghvi  staff  311888 Dec  6 12:38 csa24.png
# -rw-r--r--  1 anishkasanghvi  staff  680581 Dec  6 12:38 csp.png
# -rw-r--r--  1 anishkasanghvi  staff  323986 Dec  6 12:38 csp24.png
# -rw-r--r--  1 anishkasanghvi  staff  270084 Dec  6 12:38 csse.png
# -rw-r--r--  1 anishkasanghvi  staff  362790 Dec  6 12:38 foundation.png
# -rw-r--r--  1 anishkasanghvi  staff   42316 Dec  6 12:38 qr.png
#
# ./csp-period-5-flowcharts:
# total 104
# -rw-r--r--  1 anishkasanghvi  staff   7375 Dec  6 12:38 conditional.png
# -rw-r--r--  1 anishkasanghvi  staff  14195 Dec  6 12:38 if-else-statement.png
# -rw-r--r--  1 anishkasanghvi  staff  26585 Dec  6 12:38 nested-conditionals.png
#
# ./fullstack:
# total 80
# -rw-r--r--  1 anishkasanghvi  staff  15371 Dec  6 12:38 newvars.png
# -rw-r--r--  1 anishkasanghvi  staff   8035 Dec  6 12:38 quickSketch.png
# -rw-r--r--  1 anishkasanghvi  staff  14073 Dec  6 12:38 variables.png
#
# ./jokes:
# total 3576
# -rw-r--r--  1 anishkasanghvi  staff  1040469 Dec  6 12:38 debug.png
# -rw-r--r--  1 anishkasanghvi  staff   245915 Dec  6 12:38 postman.png
# -rw-r--r--  1 anishkasanghvi  staff   533869 Dec  6 12:38 run.png
#
# ./jpa-lesson-images:
# total 1480
# -rw-r--r--  1 anishkasanghvi  staff   15657 Dec  6 12:38 columnName.jpg
# -rw-r--r--  1 anishkasanghvi  staff   48430 Dec  6 12:38 email.jpg
# -rw-r--r--  1 anishkasanghvi  staff   83139 Dec  6 12:38 haslastname.jpg
# -rw-r--r--  1 anishkasanghvi  staff   85779 Dec  6 12:38 jpa.jpg
# -rw-r--r--  1 anishkasanghvi  staff  201269 Dec  6 12:38 largeterminal.jpg
# -rw-r--r--  1 anishkasanghvi  staff   62635 Dec  6 12:38 partial.jpg
# -rw-r--r--  1 anishkasanghvi  staff   75480 Dec  6 12:38 postman.jpg
# -rw-r--r--  1 anishkasanghvi  staff   42227 Dec  6 12:38 search2.jpg
# -rw-r--r--  1 anishkasanghvi  staff   27237 Dec  6 12:38 userJpaRepositoryFile.jpg
# -rw-r--r--  1 anishkasanghvi  staff   37602 Dec  6 12:38 userTable.jpg
# -rw-r--r--  1 anishkasanghvi  staff   56784 Dec  6 12:38 walloftext.jpg
#
# ./kasm:
# total 6936
# -rw-r--r--  1 anishkasanghvi  staff  2185677 Dec  6 12:38 kasmUI.png
# -rw-r--r--  1 anishkasanghvi  staff   234406 Dec  6 12:38 kasmlogin.png
# -rw-r--r--  1 anishkasanghvi  staff    37539 Dec  6 12:38 kasmsignup.png
# -rw-r--r--  1 anishkasanghvi  staff   138312 Dec  6 12:38 kasmv2.png
# -rw-r--r--  1 anishkasanghvi  staff   567508 Dec  6 12:38 launch.png
# -rw-r--r--  1 anishkasanghvi  staff    99833 Dec  6 12:38 ncslogin.png
# -rw-r--r--  1 anishkasanghvi  staff   274370 Dec  6 12:38 vskasm.png
#
# ./nitd_rpg:
# total 1648
# -rw-r--r--  1 anishkasanghvi  staff    5537 Dec  6 12:38 maze3.png
# -rw-r--r--  1 anishkasanghvi  staff  833503 Dec  6 12:38 mort.png
#
# ./notebooks:
# total 0
# drwxr-xr-x  6 anishkasanghvi  staff  192 Dec  6 12:38 foundation
#
# ./notebooks/foundation:
# total 728
# -rw-r--r--  1 anishkasanghvi  staff  310743 Dec  6 12:38 create_repo.png
# -rw-r--r--  1 anishkasanghvi  staff   29416 Dec  6 12:38 push.jpg
# -rw-r--r--  1 anishkasanghvi  staff   17105 Dec  6 12:38 stage.jpg
# -rw-r--r--  1 anishkasanghvi  staff    6659 Dec  6 12:38 wsl.jpg
#
# ./p1group1images:
# total 5192
# -rw-r--r--  1 anishkasanghvi  staff  298836 Dec  6 12:38 img1.png
# -rw-r--r--  1 anishkasanghvi  staff  198859 Dec  6 12:38 img10.png
# -rw-r--r--  1 anishkasanghvi  staff  172936 Dec  6 12:38 img11.png
# -rw-r--r--  1 anishkasanghvi  staff  187299 Dec  6 12:38 img2.png
# -rw-r--r--  1 anishkasanghvi  staff  247545 Dec  6 12:38 img3.png
# -rw-r--r--  1 anishkasanghvi  staff  320854 Dec  6 12:38 img4.png
# -rw-r--r--  1 anishkasanghvi  staff  267925 Dec  6 12:38 img5.png
# -rw-r--r--  1 anishkasanghvi  staff  311500 Dec  6 12:38 img6.png
# -rw-r--r--  1 anishkasanghvi  staff  190933 Dec  6 12:38 img7.png
# -rw-r--r--  1 anishkasanghvi  staff  297327 Dec  6 12:38 img8.png
# -rw-r--r--  1 anishkasanghvi  staff  142541 Dec  6 12:38 img9.png
#
# ./platformer:
# total 248
# -rw-r--r--   1 anishkasanghvi  staff    841 Dec  6 12:38 1_lopez.png
# -rw-r--r--   1 anishkasanghvi  staff   8525 Dec  6 12:38 Untitled drawing.png
# -rw-r--r--   1 anishkasanghvi  staff  91596 Dec  6 12:38 background.png
# drwxr-xr-x  33 anishkasanghvi  staff   1056 Dec  6 12:38 backgrounds
# -rw-r--r--   1 anishkasanghvi  staff  15406 Dec  6 12:38 favicon.ico
# drwxr-xr-x  21 anishkasanghvi  staff    672 Dec  6 12:38 obstacles
# drwxr-xr-x  28 anishkasanghvi  staff    896 Dec  6 12:38 platforms
# drwxr-xr-x  35 anishkasanghvi  staff   1120 Dec  6 12:38 sprites
# drwxr-xr-x  11 anishkasanghvi  staff    352 Dec  6 12:38 transitions
#
# ./platformer/backgrounds:
# total 21536
# -rw-r--r--  1 anishkasanghvi  staff   989059 Dec  6 12:38 BossBackground.png
# -rw-r--r--  1 anishkasanghvi  staff   916487 Dec  6 12:38 Congratulations!!!.png
# -rw-r--r--  1 anishkasanghvi  staff    23764 Dec  6 12:38 avenidawide3.jpg
# -rw-r--r--  1 anishkasanghvi  staff    10759 Dec  6 12:38 bat.png
# -rw-r--r--  1 anishkasanghvi  staff    71134 Dec  6 12:38 castles.png
# -rw-r--r--  1 anishkasanghvi  staff    32795 Dec  6 12:38 clouds.png
# -rw-r--r--  1 anishkasanghvi  staff     3048 Dec  6 12:38 deerMaleCalciumtrice.png
# -rw-r--r--  1 anishkasanghvi  staff   180238 Dec  6 12:38 desertbg.png
# -rw-r--r--  1 anishkasanghvi  staff    43261 Dec  6 12:38 devil.png
# -rw-r--r--  1 anishkasanghvi  staff    61795 Dec  6 12:38 flyingplayers.png
# -rw-r--r--  1 anishkasanghvi  staff    47684 Dec  6 12:38 game_over.png
# -rw-r--r--  1 anishkasanghvi  staff    33177 Dec  6 12:38 greek.png
# -rw-r--r--  1 anishkasanghvi  staff   232046 Dec  6 12:38 hills.png
# -rw-r--r--  1 anishkasanghvi  staff   160593 Dec  6 12:38 home.png
# -rw-r--r--  1 anishkasanghvi  staff    28317 Dec  6 12:38 icewater.png
# -rw-r--r--  1 anishkasanghvi  staff   150548 Dec  6 12:38 mini.png
# -rw-r--r--  1 anishkasanghvi  staff   258834 Dec  6 12:38 miniHogwarts.png
# -rw-r--r--  1 anishkasanghvi  staff    29894 Dec  6 12:38 moon.jpg
# -rw-r--r--  1 anishkasanghvi  staff   194001 Dec  6 12:38 mountains.jpg
# -rw-r--r--  1 anishkasanghvi  staff  3804266 Dec  6 12:38 multiplayerbackground.png
# -rw-r--r--  1 anishkasanghvi  staff   101005 Dec  6 12:38 narwhal.png
# -rw-r--r--  1 anishkasanghvi  staff   663965 Dec  6 12:38 planet.jpg
# -rw-r--r--  1 anishkasanghvi  staff   230522 Dec  6 12:38 podium.jpg
# -rw-r--r--  1 anishkasanghvi  staff    48819 Dec  6 12:38 quidditch2.jpg
# -rw-r--r--  1 anishkasanghvi  staff   328600 Dec  6 12:38 reef.png
# -rw-r--r--  1 anishkasanghvi  staff   188425 Dec  6 12:38 school-fish.png
# -rw-r--r--  1 anishkasanghvi  staff   863997 Dec  6 12:38 skibidiCompletion.png
# -rw-r--r--  1 anishkasanghvi  staff      721 Dec  6 12:38 snowfall.png
# -rw-r--r--  1 anishkasanghvi  staff   543088 Dec  6 12:38 springfield.png
# -rw-r--r--  1 anishkasanghvi  staff   599642 Dec  6 12:38 water.png
# -rw-r--r--  1 anishkasanghvi  staff   118454 Dec  6 12:38 winter.png
#
# ./platformer/obstacles:
# total 1720
# -rw-r--r--  1 anishkasanghvi  staff   81268 Dec  6 12:38 Chest.png
# -rw-r--r--  1 anishkasanghvi  staff   33120 Dec  6 12:38 Trident.png
# -rw-r--r--  1 anishkasanghvi  staff   25554 Dec  6 12:38 blue-tube-up.png
# -rw-r--r--  1 anishkasanghvi  staff   25477 Dec  6 12:38 blue-tube.png
# -rw-r--r--  1 anishkasanghvi  staff   32653 Dec  6 12:38 cabin.png
# -rw-r--r--  1 anishkasanghvi  staff   16925 Dec  6 12:38 coin.png
# -rw-r--r--  1 anishkasanghvi  staff   23107 Dec  6 12:38 coinanimation.png
# -rw-r--r--  1 anishkasanghvi  staff   43191 Dec  6 12:38 dimonds.png
# -rw-r--r--  1 anishkasanghvi  staff   66987 Dec  6 12:38 flag.png
# -rw-r--r--  1 anishkasanghvi  staff   24701 Dec  6 12:38 iceberg.png
# -rw-r--r--  1 anishkasanghvi  staff    7163 Dec  6 12:38 laser.png
# -rw-r--r--  1 anishkasanghvi  staff   11955 Dec  6 12:38 snitch.png
# -rw-r--r--  1 anishkasanghvi  staff   22801 Dec  6 12:38 snowflake.png
# -rw-r--r--  1 anishkasanghvi  staff   19408 Dec  6 12:38 star.png
# -rw-r--r--  1 anishkasanghvi  staff   60071 Dec  6 12:38 toilet.png
# -rw-r--r--  1 anishkasanghvi  staff  248218 Dec  6 12:38 tree.png
# -rw-r--r--  1 anishkasanghvi  staff   29442 Dec  6 12:38 tube.png
# -rw-r--r--  1 anishkasanghvi  staff   21876 Dec  6 12:38 vbucks.png
# -rw-r--r--  1 anishkasanghvi  staff   48319 Dec  6 12:38 whompingwillowtree.png
#
# ./platformer/platforms:
# total 4688
# -rw-r--r--  1 anishkasanghvi  staff     8474 Dec  6 12:38 Chocolatefrog.jpg
# -rw-r--r--  1 anishkasanghvi  staff    75783 Dec  6 12:38 alien.png
# -rw-r--r--  1 anishkasanghvi  staff    41211 Dec  6 12:38 brick_block.png
# -rw-r--r--  1 anishkasanghvi  staff     2782 Dec  6 12:38 brick_wall.png
# -rw-r--r--  1 anishkasanghvi  staff    10690 Dec  6 12:38 bubbles.png
# -rw-r--r--  1 anishkasanghvi  staff     6537 Dec  6 12:38 cobblestone.png
# -rw-r--r--  1 anishkasanghvi  staff    26145 Dec  6 12:38 grass.png
# -rw-r--r--  1 anishkasanghvi  staff    56810 Dec  6 12:38 ground.png
# -rw-r--r--  1 anishkasanghvi  staff    15969 Dec  6 12:38 island.png
# -rw-r--r--  1 anishkasanghvi  staff    84023 Dec  6 12:38 lava.jpg
# -rw-r--r--  1 anishkasanghvi  staff    23906 Dec  6 12:38 lionpattern.jpg
# -rw-r--r--  1 anishkasanghvi  staff   143056 Dec  6 12:38 magic_beam.png
# -rw-r--r--  1 anishkasanghvi  staff    66332 Dec  6 12:38 mario_block_spritesheet_v2.png
# -rw-r--r--  1 anishkasanghvi  staff    27915 Dec  6 12:38 mushroom.png
# -rw-r--r--  1 anishkasanghvi  staff     4921 Dec  6 12:38 narwhalfloor.png
# -rw-r--r--  1 anishkasanghvi  staff   115313 Dec  6 12:38 rockslava.png
# -rw-r--r--  1 anishkasanghvi  staff    64074 Dec  6 12:38 sand.png
# -rw-r--r--  1 anishkasanghvi  staff      298 Dec  6 12:38 sandblock.png
# -rw-r--r--  1 anishkasanghvi  staff     8076 Dec  6 12:38 sandstone.png
# -rw-r--r--  1 anishkasanghvi  staff    55870 Dec  6 12:38 skibidiBlock.png
# -rw-r--r--  1 anishkasanghvi  staff   330989 Dec  6 12:38 snowyfloor.png
# -rw-r--r--  1 anishkasanghvi  staff     7447 Dec  6 12:38 snowywood.png
# -rw-r--r--  1 anishkasanghvi  staff    39059 Dec  6 12:38 stone.jpg
# -rw-r--r--  1 anishkasanghvi  staff  1092399 Dec  6 12:38 turf.png
# -rw-r--r--  1 anishkasanghvi  staff    27827 Dec  6 12:38 yellowredpattern.jpg
# -rw-r--r--  1 anishkasanghvi  staff    17518 Dec  6 12:38 yellowtowerpattern.jpg
#
# ./platformer/sprites:
# total 17536
# -rw-r--r--  1 anishkasanghvi  staff    38055 Dec  6 12:38 alert.gif
# -rw-r--r--  1 anishkasanghvi  staff    51640 Dec  6 12:38 alien.png
# -rw-r--r--  1 anishkasanghvi  staff   120450 Dec  6 12:38 boss.png
# -rw-r--r--  1 anishkasanghvi  staff     6736 Dec  6 12:38 canelopezspritesheet.png
# -rw-r--r--  1 anishkasanghvi  staff     3167 Dec  6 12:38 cerberus.png
# -rw-r--r--  1 anishkasanghvi  staff   103701 Dec  6 12:38 dementor2.png
# -rw-r--r--  1 anishkasanghvi  staff   155641 Dec  6 12:38 dog.png
# -rw-r--r--  1 anishkasanghvi  staff    49625 Dec  6 12:38 dracomalfoy.png
# -rw-r--r--  1 anishkasanghvi  staff    24281 Dec  6 12:38 dragon.png
# -rw-r--r--  1 anishkasanghvi  staff   141829 Dec  6 12:38 escaper.png
# -rw-r--r--  1 anishkasanghvi  staff   121796 Dec  6 12:38 flying-goomba.png
# -rw-r--r--  1 anishkasanghvi  staff   356155 Dec  6 12:38 flying-ufo.png
# -rw-r--r--  1 anishkasanghvi  staff   121815 Dec  6 12:38 goomba.png
# -rw-r--r--  1 anishkasanghvi  staff    91068 Dec  6 12:38 goombaspritesheet.png
# -rw-r--r--  1 anishkasanghvi  staff    14232 Dec  6 12:38 harryanimation2.png
# -rw-r--r--  1 anishkasanghvi  staff    15902 Dec  6 12:38 harryanimation3.png
# -rw-r--r--  1 anishkasanghvi  staff    15969 Dec  6 12:38 island.png
# -rw-r--r--  1 anishkasanghvi  staff   164132 Dec  6 12:38 jellyfish.png
# -rw-r--r--  1 anishkasanghvi  staff   162387 Dec  6 12:38 knight.png
# -rw-r--r--  1 anishkasanghvi  staff    17116 Dec  6 12:38 lopezanimation.png
# -rw-r--r--  1 anishkasanghvi  staff     6609 Dec  6 12:38 lopezspritesheet3.png
# -rwxr-xr-x  1 anishkasanghvi  staff  3851947 Dec  6 12:38 mario.png
# -rw-r--r--  1 anishkasanghvi  staff   111425 Dec  6 12:38 monkey.png
# -rw-r--r--  1 anishkasanghvi  staff    49605 Dec  6 12:38 narwhal_boss.png
# -rw-r--r--  1 anishkasanghvi  staff   181376 Dec  6 12:38 noirio.png
# -rw-r--r--  1 anishkasanghvi  staff    59931 Dec  6 12:38 owl.png
# -rw-r--r--  1 anishkasanghvi  staff    23940 Dec  6 12:38 penguin.png
# -rw-r--r--  1 anishkasanghvi  staff   457104 Dec  6 12:38 skibidiEnemy.png
# -rw-r--r--  1 anishkasanghvi  staff   155875 Dec  6 12:38 skibidiTItan.png
# -rw-r--r--  1 anishkasanghvi  staff    26141 Dec  6 12:38 snowman.png
# -rw-r--r--  1 anishkasanghvi  staff  1683899 Dec  6 12:38 white_mario.png
# -rw-r--r--  1 anishkasanghvi  staff   376506 Dec  6 12:38 white_mario1.png
# -rw-r--r--  1 anishkasanghvi  staff   152460 Dec  6 12:38 zombie.png
#
# ./platformer/transitions:
# total 9512
# -rw-r--r--  1 anishkasanghvi  staff  123315 Dec  6 12:38 IceMinigameEnd.png
# -rw-r--r--  1 anishkasanghvi  staff  750112 Dec  6 12:38 greeceEnd.png
# -rw-r--r--  1 anishkasanghvi  staff   20774 Dec  6 12:38 greenscreen.png
# -rw-r--r--  1 anishkasanghvi  staff  951532 Dec  6 12:38 hillsEnd.png
# -rw-r--r--  1 anishkasanghvi  staff  211655 Dec  6 12:38 hogwartsminiEnd.jpg
# -rw-r--r--  1 anishkasanghvi  staff  859809 Dec  6 12:38 miniEnd.png
# -rw-r--r--  1 anishkasanghvi  staff  917436 Dec  6 12:38 quidditchEnd.png
# -rw-r--r--  1 anishkasanghvi  staff  917788 Dec  6 12:38 waterEnd.png
# -rw-r--r--  1 anishkasanghvi  staff   94865 Dec  6 12:38 winterEnd.png
#
# ./rpg:
# total 1280
# -rw-r--r--  1 anishkasanghvi  staff   33742 Dec  6 12:38 fishies.png
# -rw-r--r--  1 anishkasanghvi  staff   13963 Dec  6 12:38 turtle.png
# -rw-r--r--  1 anishkasanghvi  staff  599642 Dec  6 12:38 water.png
#
# ./u8-p1-assets:
# total 416
# -rw-r--r--  1 anishkasanghvi  staff  103745 Dec  6 12:38 qp1.png
# -rw-r--r--  1 anishkasanghvi  staff  102436 Dec  6 12:38 qp2.png

# %% [markdown]
# ### Look inside a Markdown File
# > "cat" reads data from the file and gives its content as output

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Navigate to project, then navigate to area wwhere files were cloned"
#
# cd $project
# echo "show the contents of README.md"
# echo ""
#
# cat README.md  # show contents of file, in this case markdown
# echo ""
# echo "end of README.md"
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# show the contents of README.md
#
# # Introduction
#
# Nighthawk Pages is a project designed to support students in their Computer Science and Software Engineering education. It offers a wide range of resources including tech talks, code examples, and educational blogs.
#
# GitHub Pages can be customized by the blogger to support computer science learnings as the student works through the pathway of using Javascript, Python/Flask, Java/Spring.
#
# ## Student Requirements
#
# Del Norte HS students will be required to review their personal GitHub Pages at each midterm and final.  This review will contain a compilation of personal work performed within each significant grading period.
#
# In general, Students and Teachers are expected to use GitHub pages to build lessons, complete classroom hacks, perform work on JavaScript games, and serve as a frontend to full-stack applications.
#
# Exchange of information could be:
#
# 1. sharing a file:  `wget "raw-link.ipynb"
# 2. creating a template from this repository
# 3. sharing a fork among team members
# 4. etc.
#
# ---
#
# ## History
#
# This project is in its 3rd revision (aka 3.0).
#
# The project was initially based on Fastpages. But this project has diverged from those roots into an independent entity.  The decision to separate from Fastpages was influenced by the deprecation of Fastpages by authors.  It is believed by our community that the authors of fastpages turned toward Quatro.  After that change of direction fastpages did not align with the Teacher's goals and student needs. The Nighthawk Pages project has more of a raw development blogging need.
#
# ### License
#
# The Apache license has its roots in Fastpages.  Thus, it carries its license forward.  However, most of the code is likely unrecognizable from those roots.
#
# ### Key Features
#
# - **Code Examples**: Provides practical coding examples in JavaScript, including a platformer game, and frontend code for user databases using Python and Java backends.
# - **Educational Blogs**: Offers instructional content on various topics such as developer tools setup, deployment on AWS, SQL databases, machine learning, and data structures. It utilizes Jupyter Notebooks for interactive lessons and coding challenges.
# - **Tools and Integrations**: Features GitHub actions for blog publishing, Utterances for blog commenting, local development support via Makefile and scripts, and styling with the Minima Theme and SASS. It also includes a new integration with GitHub Projects and Issues.
#
# ### Contributions
#
# - **Notable Contributions**: Highlights significant contributions to the project, including theme development, search and tagging functionality, GitHub API integration, and the incorporation of GitHub Projects into GitHub pages. Contributors such as Tirth Thakker, Mirza Beg, and Toby Ledder have played crucial roles in these developments.
#
# - **Blog Contributions**:  Often students contribute articles and blogs to this project.  Their names are typically listed in the front matter of their contributing post.
#
# ---
#
# ## GitHub Pages setup
#
# The absolutes in setup up...
#
# **Activate GitHub Pages Actions**: This step involves enabling GitHub Pages Actions for your project. By doing so, your project will be automatically deployed using GitHub Pages Actions, ensuring that your project is always up to date with the latest changes you push to your repository.
#
# - On the GitHub website for the repository go to the menu: Settings -> Pages ->Build
# - Under the Deployment location on the page, select "GitHub Actions".
#
# **Update `_config.yml`**: You need to modify the `_config.yml` file to reflect your repository's name. This configuration is crucial because it ensures that your project's styling is correctly applied, making your deployed site look as intended rather than unstyled or broken.
#
# ```text
# github_repo: "portfolio_2025"
# baseurl: "/portfolio_2025"
# ```
#
# **Set Repository Name in Makefile**: Adjust the `REPO_NAME` variable in your Makefile to match your GitHub repository's name. This action facilitates the automatic updating of posts and notebooks on your local development server, improving the development process.
#
# ```make
# # Configuration, override port with usage: make PORT=4200
# PORT ?= 4100
# REPO_NAME ?= portfolio_2025
# LOG_FILE = /tmp/jekyll$(PORT).log
# ```
#
# ### Tool requirements
#
# All `GitHub Pages` websites are managed on GitHub infrastructure and use GitHub version control.  Each time we change files in GitHub it initiates a GitHub Action, a continuous integration and development toolset, that rebuilds and publishes the site with Jekyll.
#
# - GitHub uses `Jekyll` to transform your markdown and HTML content into static websites and blogs. [Jekyll](https://jekyllrb.com/).
# - A Linux shell is required to work with this project integration with GitHub Pages, GitHub and VSCode.  Ubuntu is the preferred shell, though MacOS shell is supported as well.  There will be some key setup scripts that follow in the README.
# - Visual Studio Code is the Nighthawk Pages author's preferred code editor and extensible development environment.  VSCode has a rich ecosystem of developer extensions that ease working with GitHub Pages, GitHub, and many programming languages.  Setting up VSCode and extensions will be elaborated upon in this document.
# - An anatomy section in this README will describe GitHub Pages and conventions that are used to organize content and files.  This includes file names, key coding files, metadata tagging of blogs, styling tooling for blogs, etc.
#
# ### Development Environment Setup
#
# Comprehensive start. A topic-by-topic guide to getting this project running is published [here](https://nighthawkcoders.github.io/portfolio_2025/devops/tools/home).
#
# Quick start.  A quick start below is a reminder, but is dependent on your knowledge.  Only follow this instruction if you need a refresher.  Always default to the comprehensive start if any problem occurs.
#
# #### Clone Repo
#
# Run these commands to obtain the project, then locate into the project directory with the terminal, install an extensive set of tools, and make.
#
# ```bash
# git clone <this-repo> # git clone https://github.com/nighthawkcoders/portfolio_2025.git
# cd <repo-dir>/scripts # cd portfolio_2025
# ```
#
# #### Windows WSL and/or Ubuntu Users
#
# - Execute the script: `./activate_ubuntu.sh`
#
# #### macOS Users
#
# - Execute the script: `./activate_macos.sh`
#
# #### Kasm Cloud Desktop Users
#
# - Execute the script: `./activate.sh`
#
# ## Run Server on localhost
#
# To preview the project you will need to "make" the project.
#
# ### Bundle install
#
# The very first time you clone run project you will need to run this Ruby command as the final part of your setup.
#
# ```bash
# bundle install
# ```
#
# ### Start the Server
#
# This requires running terminal commands `make`, `make stop`, `make clean`, or `make convert` to manage the running server.  Logging of details will appear in the terminal.   A `Makefile` has been created in the project to support commands and start processes.
#
# Start the server, this is the best choice for initial and iterative development.  Note. after the initial `make`, you should see files automatically refresh in the terminal on VSCode save.
#
#   ```bash
#   make
#   ```
#
# ### Load web application into the Browser
#
# Start the preview server in the terminal,
# The terminal output from `make` shows the server address. "Cmd" or "Ctl" click the http location to open the preview server in a browser. Here is an example Server address message, click on the Server address to load:...
#
#   ```text
#   http://0.0.0.0:4100/portfolio_2025/
#   ```
#
# ### Regeneration of web application
#
# Save on ".ipynb" or ".md" file activiates "regeneration". An example terminal message is below.  Refresh the browser to see updates after the message displays.
#
#   ```text
#   Regenerating: 1 file(s) changed at 2023-07-31 06:54:32
#       _notebooks/2024-01-04-cockpit-setup.ipynb
#   ```
#
# ### Other "make" commands
#
# Terminal messages are generated from background processes.  At any time, click return or enter in a terminal window to obtain a prompt.  Once you have the prompt you can use the terminal as needed for other tasks.  Always return to the root of project `cd ~/vscode/portfolio_2025` for all "make" actions.
#
# #### Stop the preview server
#
# Stopping the server ends the web server applications running process.  However, it leaves constructed files in the project in a ready state for the next time you run `make`.
#
#   ```bash
#   make stop
#   ```
#
# ### Clean the local web application environment
#
# This command will top the server and "clean" all previously constructed files (ie .ipynb -> .md). This is the best choice when renaming files has created duplicates that are visible when previewing work.
#
#   ```bash
#   make clean
#   ```
#
# ### Observe build errors
#
# Test Jupyter Notebook conversions (ie .ipynb -> .md), this is the best choice to see if an IPYNB conversion error is occurring.
#
#   ```bash
#   make convert
#   ```
#
# ---
#
# ## Development Support
#
# ### File Names in "_posts", "_notebooks"
#
# There are two primary directories for creating blogs.  The "_posts" directory is for authoring in markdown only.  The "_notebooks" allows for markdown, pythons, javascript and more.
#
# To name a file, use the following structure (If dates are in the future, review your config.yml setting if you want them to be viewed).  Review these naming conventions.
#
# - For markdown files in _posts:
#   - year-month-day-fileName.md
#     - GOOD EXAMPLE: 2021-08-02-First-Day.md
#     - BAD EXAMPLE: 2021-8-2-first-day.md
#     - BAD EXAMPLE: first-day.md
#     - BAD EXAMPLE: 2069-12-31-First-Day.md
#
# - For Jupyter notebooks in _notebooks:
#   - year-month-day-fileName.ipynb
#     - GOOD EXAMPLE: 2021-08-02-First-Day.ipynb
#     - BAD EXAMPLE: 2021-8-2-first-day.ipynb
#     - BAD EXAMPLE: first-day.ipynb
#     - BAD EXAMPLE: 2069-12-31-First-Day.ipynb
#
# ### Tags
#
# Tags are used to organize pages by their tag the way to add tags is to add the following to your front matter such as the example seen here `categories: [Tools]` Each item in the same category will be lumped together to be seen easily on the search page.
#
# ### Search
#
# All pages can be searched for using the built-in search bar. This search bar will search for any word in the title of a page or in the page itself. This allows for easily finding pages and information that you are looking for. However, sometimes this may not be desirable so to hide a page from the search you need to add `search_exclude: true` to the front matter of the page. This will hide the page from appearing when the viewer uses search.
#
# ### Navigation Bar
#
# To add pages to the top navigation bar use _config.yml to order and determine which menus you want and how to order them.  Review the_config.yml in this project for an example.
#
# ### Blog Page
#
# There is a blog page that has options for images and a description of the page. This page can help the viewer understand what the page is about and what they can expect to find on the page. The way to add images to a page is to have the following front matter `image: /images/file.jpg` and then the name of the image that you want to use. The image must be in the `images` folder. Furthermore, if you would like the file to not show up on the blog page `hide: true` can be added to the front matter.
#
# ### SASS support
#
# NIGHTHAWK Pages support a variety of different themes that are each overlaid on top of minima. To use each theme, go to the "_sass/minima/custom-styles.scss" file and simply comment or uncomment the theme you want to use.
#
# To learn about the minima themes search for "GitHub Pages minima" and review the README.
#
# To find a new theme search for "Github Pages Themes".
#
# ### Includes
#
# - Nighthawk Pages uses liquid syntax to import many common page elements that are present throughout the repository. These common elements are imported from the _includes directory. If you want to add one of these common elements, use liquid syntax to import the desired element to your file. Here’s an example of the liquid syntax used to import: `{%- include post_list.html -%}` Note that the liquid syntax is surrounded by curly braces and percent signs. This can be used anywhere in the repository.
#
# ### Layouts
#
# - To use or create a custom page layout, make an HTML page inside the _layouts directory, and when you want to use that layout in a file, use the following front matter `layout: [your layout here]`.  All layouts will be written in liquid to define the structure of the page.
#
# ### Metadata
#
# Metadata, also known as "front matter", is a set of key-value pairs that can provide additional information to GitHub Pages about .md and .ipynb files. This can and probably will be used in other file types (ie doc, pdf) if we add them to the system.
#
# In the front matter, you can also define things like a title and description for the page.  Additional front matter is defined to place content on the "Computer Science Lab Notebook" page.  The `courses:` key will place data on a specific page with the nested `week:` placing data on a specific row on the page.  The `type:` key in "front matter" will place the blog under the plans, hacks(ToDo), and tangibles columns.
#
# - In our files, the front matter is defined at the top of the page or the first markdown cell.
#
#   - First, open one of the .md or .ipynb files already included in either your _posts|_notebooks folder.
#
#   - In the .md file, you should notice something similar to this at the top of the page. To see this in your .ipynb files you will need to double-click the markdown cell at the top of the file.
#
#   ```yaml
#   ---
#   toc: true
#   comments: true
#   layout: post
#   title: Jupyter Python Sample
#   description: Example Blog!!!  This shows code and notes from hacks.
#   type: ccc
#   courses: { csa: {week: 5} }
#   ---
#   ```
#
# - The front matter will always have '---' at the top and bottom to distinguish it and each key-value pair will be separated by a ':'.
#
# - Here we can modify things like the title and description.
#
# - The type value will tell us which column this is going to appear under the time box supported pages.  The "ccc" stands for Code, Code, Code.
#
# - The courses will tell us which menu item it will be under, in this case, the `csa` menu, and the `week` tells it what row (week) it will appear under that menu.
#
# end of README.md

# %% [markdown]
# ## Env, Git, and GitHub
#
# > Env(ironment) is used to capture things like the path to the Code or Home directory. Git and GitHub are not only used to exchange code between individuals but are also often used to exchange code through servers, in our case for website deployment. All tools we use have behind-the-scenes relationships with the system they run on (MacOS, Windows, Linux) or a relationship with servers to which they are connected (e.g., GitHub). There is an "env" command in bash. There are environment files and setting files (e.g., `.git/config`) for Git. They both use a key/value concept.
#
# - `env` shows settings for your shell.
# - `git clone` sets up a directory of files.
# - `cd $project` allows the user to move inside that directory of files.
# - `.git` is a hidden directory that is used by Git to establish a relationship between the machine and the Git server on GitHub.

# %%
# %%script bash
#
# # This command has no dependencies
#
# echo "Show the shell environment variables, key on left of equal value on right"
# echo ""
#
# env
# Out:
# Show the shell environment variables, key on left of equal value on right
#
# NVM_INC=/Users/anishkasanghvi/.nvm/versions/node/v16.20.2/include/node
# MANPATH=/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/share/man:/Library/Developer/CommandLineTools/usr/share/man:/Library/Developer/CommandLineTools/Toolchains/XcodeDefault.xctoolchain/usr/share/man:
# VSCODE_CRASH_REPORTER_PROCESS_TYPE=extensionHost
# NVM_CD_FLAGS=-q
# GEM_HOME=/Users/anishkasanghvi/gems
# TERM=xterm-color
# SHELL=/bin/zsh
# CLICOLOR=1
# TMPDIR=/var/folders/90/byh0hvdd5pdb74z4yxs9m81h0000gn/T/
# HOMEBREW_REPOSITORY=/opt/homebrew
# LIBRARY_PATH=/usr/local/lib
# PYTHONUNBUFFERED=1
# SDKROOT=/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk
# ORIGINAL_XDG_CURRENT_DESKTOP=undefined
# MallocNanoZone=0
# PYDEVD_USE_FRAME_EVAL=NO
# PYTHONIOENCODING=utf-8
# USER=anishkasanghvi
# NVM_DIR=/Users/anishkasanghvi/.nvm
# COMMAND_MODE=unix2003
# CPATH=/usr/local/include
# SSH_AUTH_SOCK=/private/tmp/com.apple.launchd.CIms8K5gbK/Listeners
# __CF_USER_TEXT_ENCODING=0x1F5:0x0:0x0
# PAGER=cat
# ELECTRON_RUN_AS_NODE=1
# PATH=/usr/bin:/Users/anishkasanghvi/Library/Python/3.9/bin:/Users/anishkasanghvi/.nvm/versions/node/v16.20.2/bin:/Users/anishkasanghvi/gems/bin:/Users/anishkasanghvi/.rbenv/shims:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Users/anishkasanghvi/.nvm/versions/node/v16.20.2/bin:/Users/anishkasanghvi/gems/bin:/Users/anishkasanghvi/.rbenv/shims:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin
# __CFBundleIdentifier=com.microsoft.VSCode
# PWD=/Users/anishkasanghvi/nighthawks/portfolio_2025_Anishka/_notebooks/Foundation/B-tools_and_equipment
# VSCODE_HANDLES_UNCAUGHT_ERRORS=true
# MPLBACKEND=module://matplotlib_inline.backend_inline
# VSCODE_ESM_ENTRYPOINT=vs/workbench/api/node/extensionHostProcess
# PYTHON_FROZEN_MODULES=on
# XPC_FLAGS=0x0
# FORCE_COLOR=1
# RBENV_SHELL=zsh
# XPC_SERVICE_NAME=0
# SHLVL=1
# HOME=/Users/anishkasanghvi
# VSCODE_NLS_CONFIG={"userLocale":"en-us","osLocale":"en-us","resolvedLanguage":"en","defaultMessagesFile":"/private/var/folders/90/byh0hvdd5pdb74z4yxs9m81h0000gn/T/AppTranslocation/94AF8E35-F6D6-4F41-8A5B-3F3C3583439B/d/Visual Studio Code.app/Contents/Resources/app/out/nls.messages.json","locale":"en-us","availableLanguages":{}}
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING=1
# HOMEBREW_PREFIX=/opt/homebrew
# LOGNAME=anishkasanghvi
# LC_CTYPE=UTF-8
# VSCODE_IPC_HOOK=/Users/anishkasanghvi/Library/Application Support/Code/1.95-main.sock
# VSCODE_CODE_CACHE_PATH=/Users/anishkasanghvi/Library/Application Support/Code/CachedData/f1a4fb101478ce6ec82fe9627c43efbf9e98c813
# CLICOLOR_FORCE=1
# NVM_BIN=/Users/anishkasanghvi/.nvm/versions/node/v16.20.2/bin
# VSCODE_PID=2153
# INFOPATH=/opt/homebrew/share/info:
# HOMEBREW_CELLAR=/opt/homebrew/Cellar
# GIT_PAGER=cat
# VSCODE_L10N_BUNDLE_LOCATION=
# VSCODE_CWD=/
# _=/usr/bin/env

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# cd $project
#
# echo ""
# echo "show the secrets of .git config file"
# cd .git
# ls -l config
#
# echo ""
# echo "look at config file"
# cat config
# Out:
# show the secrets of .git config file
# -rw-r--r--  1 anishkasanghvi  staff  356 Dec  6 12:38 config
#
# look at config file
# [core]
# 	repositoryformatversion = 0
# 	filemode = true
# 	bare = false
# 	logallrefupdates = true
# 	ignorecase = true
# 	precomposeunicode = true
# [remote "origin"]
# 	url = https://github.com/SpaceGirl13/portfolio_2025_Anishka.git
# 	fetch = +refs/heads/*:refs/remotes/origin/*
# [branch "main"]
# 	remote = origin
# 	merge = refs/heads/main
# 	vscode-merge-base = origin/main

# %% [markdown]
# ## Advanced Shell project
#
# > This example was requested by a student (Jun Lim, CSA). The request was to make a Jupyter file using bash; I adapted the request to markdown. This type of thought will have great extrapolation to coding and possibilities of using Lists, Arrays, or APIs to build user interfaces. JavaScript is a language where building HTML is very common.
#
# > To get more interesting output from the terminal, this will require using something like mdless (https://github.com/ttscoff/mdless). This enables seeing markdown in rendered format.
# - On Desktop [Install PKG from MacPorts](https://www.macports.org/install.php)
# - In Terminal on MacOS
#     - [Install ncurses](https://ports.macports.org/port/ncurses/)
#     - ```gem install mdless```
#
# > Output of the example is much nicer in "Jupyter"
#
# This is starting the process of documentation.

# %%
# %%script bash
#
# # This example has an error in VSCode; it runs best on Jupyter
# cd /tmp
#
# file="sample.md"
# if [ -f "$file" ]; then
#     rm $file
# fi
#
# # Create a markdown file using tee and here document (<<EOF)
# tee -a $file >/dev/null <<EOF
# # Show Generated Markdown
# This introductory paragraph and this line and the title above are generated using tee with the standard input (<<) redirection operator.
# - This bulleted element is still part of the tee body.
# EOF
#
# # Append additional lines to the markdown file using echo and redirection (>>)
# echo "- This bulleted element and lines below are generated using echo with standard output (>>) redirection operator." >> $file
# echo "- The list definition, as is, is using space to separate lines. Thus the use of commas and hyphens in output." >> $file
#
# # Define an array of actions and their descriptions
# actions=("ls,list-directory" "cd,change-directory" "pwd,present-working-directory" "if-then-fi,test-condition" "env,bash-environment-variables" "cat,view-file-contents" "tee,write-to-output" "echo,display-content-of-string" "echo_text_>\$file,write-content-to-file" "echo_text_>>\$file,append-content-to-file")
#
# # Loop through the actions array and append each action to the markdown file
# for action in ${actions[@]}; do
#   action=${action//-/ }  # Convert dash to space
#   action=${action//,/: } # Convert comma to colon
#   action=${action//_text_/ \"sample text\" } # Convert _text_ to "sample text", note escape character \ to avoid "" having meaning
#   echo "    - ${action//-/ }" >> $file  # Append action to file
# done
#
# echo ""
# echo "File listing and status"
# ls -l $file # List file details
# wc $file   # Show word count
# mdless $file  # Render markdown from terminal (requires mdless installation)
#
# rm $file  # Clean up temporary file
# Out:
# File listing and status
# -rw-r--r--@ 1 anishkasanghvi  wheel  808 Dec 12 11:52 sample.md
#       15     132     808 sample.md
# bash: line 36: mdless: command not found

# %% [markdown]
# ## Display Shell commands help using `man`
#
# > The previous example used a markdown file to store a list of actions and their descriptions. This example uses the `man` command to generate a markdown file with descriptions of the commands. The markdown file is then displayed using `mdless`.
#
# In coding, we should try to get data from the content creators instead of creating it on our own. This approach has several benefits:
# - **Accuracy**: Descriptions from `man` pages are authoritative and accurate, as they come directly from the documentation provided by the command's developers.
# - **Consistency**: Automatically generating descriptions ensures consistency in formatting and terminology.
# - **Efficiency**: It saves time and effort, especially when dealing with a large number of commands.
# - **Up-to-date Information**: `man` pages are regularly updated with the latest information, ensuring that the descriptions are current.

# %%
# %%script bash
#
# # This example has an error in VSCode; it runs best on Jupyter
# cd /tmp
#
# file="sample.md"
# if [ -f "$file" ]; then
#     rm $file
# fi
#
# # Set locale to C to avoid locale-related errors
# export LC_ALL=C
#
# # Create a markdown file using tee and here document (<<EOF)
# tee -a $file >/dev/null <<EOF
# # Show Generated Markdown
# This introductory paragraph and this line and the title above are generated using tee with the standard input (<<) redirection operator.
# - This bulleted element is still part of the tee body.
# EOF
#
# # Append additional lines to the markdown file using echo and redirection (>>)
# echo "- This bulleted element and lines below are generated using echo with standard output (>>) redirection operator." >> $file
# echo "- The list definition, as is, is using space to separate lines. Thus the use of commas and hyphens in output." >> $file
#
# # Define an array of commands
# commands=("ls" "cat" "tail" "pwd" "env" "grep" "awk" "sed" "curl" "wget")
#
# # Loop through the commands array and append each command description to the markdown file
# for cmd in ${commands[@]}; do
#   description=$(man $cmd | col -b | awk '/^NAME/{getline; print}')
#   echo "    - $description" >> $file
# done
#
# echo ""
# echo "File listing and status"
# ls -l $file # List file details
# wc $file   # Show word count
# mdless $file  # Render markdown from terminal (requires mdless installation)
#
# rm $file  # Clean up temporary file
# Out:
# No manual entry for wget
# File listing and status
# -rw-r--r--@ 1 anishkasanghvi  wheel  919 Dec 12 11:52 sample.md
#       15     145     919 sample.md
# bash: line 37: mdless: command not found
